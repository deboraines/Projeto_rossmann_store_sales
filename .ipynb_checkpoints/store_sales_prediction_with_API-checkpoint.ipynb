# %% [markdown]
# # 0.0. IMPORTS

# %%
import math
import random
import pickle
import warnings
import numpy as np
import pandas as pd
import inflection
import seaborn as sns
import xgboost as xgb
import json
import requests

from scipy                import stats
from boruta               import BorutaPy
from tabulate             import tabulate
from matplotlib           import pyplot as plt
from IPython.display      import Image
from IPython.core.display import HTML

from sklearn.metrics       import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.ensemble      import RandomForestRegressor
from sklearn.linear_model  import LinearRegression, Lasso
from sklearn.preprocessing import RobustScaler, MinMaxScaler, LabelEncoder

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 0.1. Helper Functions

# %%
# Function Cross Validation
def cross_validation(x_training, kfold, model_name, model, verbose=False): # verbose=False: se nenhum parametro for passado ele subscreve

    # list for calculate mean and std
    mae_list = []
    mape_list = []
    rmse_list = []
    for k in reversed(range(1, kfold+1)):
        if verbose:
            print('\nKFold Number: {}'.format(k))
        # Primeira data da validação (começa 6 semanas antes do final)
        validation_start_date = x_training['date'].max() - datetime.timedelta(days= k*6*7)

        # Última data da validação (última data)
        validation_end_date = x_training['date'].max() - datetime.timedelta(days= (k-1)*6*7)

        # Filtering dataset (menor que o início do validation_start_date)
        training = x_training[x_training['date'] < validation_start_date]
        validation = x_training[(x_training['date'] >= validation_start_date) & (x_training['date'] <= validation_end_date)]

        # Training and validation dataset
        # training
        xtraining = training.drop(['date', 'sales'], axis=1)
        ytraining = training['sales']

        # validation
        xvalidation = validation.drop(['date', 'sales'], axis=1)
        yvalidation = validation['sales']

        # model
        m = model.fit(xtraining, ytraining)

        # prediction
        yhat = m.predict(xvalidation)

        # performance
        m_result = ml_error(model_name, np.expm1(yvalidation), np.expm1(yhat)) # expm1 = exponencial para voltar o log no valor original

        # Store performance of each kfold iteration
        mae_list.append(m_result['MAE'])
        mape_list.append(m_result['MAPE'])
        rmse_list.append(m_result['RMSE'])

    return pd.DataFrame({'Model Name': model_name,
                         'MAE CV': np.round(np.mean(mae_list), 2).astype(str) + ' +/- ' + np.round(np.std(mae_list), 2).astype(str),
                         'MAPE CV': np.round(np.mean(mape_list), 2).astype(str) + ' +/- ' + np.round(np.std(mape_list), 2).astype(str),
                         'RMSE CV': np.round(np.mean(rmse_list), 2).astype(str) + ' +/- ' + np.round(np.std(rmse_list), 2).astype(str) }, index=[0])

# Function ML Error
def ml_error(model_name, y, yhat): # model_name = nome do modelo, y = valores reais, yhat = valores preditos (estimativas)
    mae = mean_absolute_error(y, yhat)
    mape = mean_absolute_percentage_error(y, yhat)
    rmse = np.sqrt(mean_squared_error(y, yhat))
    
    return pd.DataFrame({'Model Name': model_name,
                         'MAE': mae,
                         'MAPE': mape,
                         'RMSE': rmse}, index=[0])
# Mean percentage error
def mean_percentage_error(y, yhat):
    return np.mean((y - yhat) / y)

# Função de Cramer V
def cramer_v(x, y):
    cm = pd.crosstab(x, y).values
    n = cm.sum()
    r, k = cm.shape
    
    chi2 = stats.chi2_contingency(cm)[0]
    chi2corr = max(0, chi2 - (k-1) * (r-1) / (n-1))
    
    kcorr = k - (k-1)**2 / (n-1)
    rcorr = r - (r-1)**2 / (n-1)
    
    return np.sqrt((chi2corr/n) / (min(kcorr-1, rcorr-1)))


def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2. Loading Data

# %%
# low_memory=False: Fala pra função read_csv ler todo o arquivo de uma vez só para a memória. Se for true vai ler de pedaço em pedaço.
df_sales_raw = pd.read_csv('/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/datasets/train.csv', low_memory = False)
df_store_raw = pd.read_csv('/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/datasets/store.csv', low_memory = False)

# merge
df_raw = pd.merge (df_sales_raw, df_store_raw, how='left', on='Store')

# %% [markdown]
# # 1.0. PASSO 01 - DESCRIÇÃO DOS DADOS

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1. Rename Columns

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo','StateHoliday', 'SchoolHoliday', 'StoreType', 
            'Assortment','CompetitionDistance', 'CompetitionOpenSinceMonth','CompetitionOpenSinceYear', 'Promo2', 
            'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']

snakecase = lambda x: inflection.underscore(x)

# faz o mapeamento da função snakecase em todas as palavras da lista cols_old, e o retorno seja uma lista para 
# fazer o rename da coluna e ai guardamos a nova lista em uma variavel nova chamada cols_news
cols_new = list(map(snakecase, cols_old))

# rename
df1.columns = cols_new

# %% [markdown]
# ## 1.2. Data Dimensions

# %%
print('Number of Rows: {}'.format(df1.shape[0]))
print('Number of Cols: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 1017209
# Number of Cols: 18

# %% [markdown]
# ## 1.3. Data Types

# %%
df1['date'] = pd.to_datetime(df1['date'])

df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4. Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5. Fillout NA

# %%
# competition_distance: se NA é porque não tem um competidor próximo da loja, ou é uma loja muito distante para ser um competidor.
# Se colocarmos uma distancia muito maior que a distância máxima que tem nos dados, é a mesma coisa que dizer que não existe um competidor próximo.
# regra: inserimos um valor baseado no max 'competition_distance' em todos NAs
df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan(x) else x)

# competition_open_since_month: mês aproximado que o competidor mais próximo foi aberto
# Se NA é porque não tem um competidor próximo da loja, ou a loja tem um competidor próximo mas não sabe a data que a loja mais próxima 
# foi aberta, uma porque a loja competidora abriu muito antes da loja ser aberta, ou porque abriu depois e alguém esqueceu de anotar.
# regra: se NA pegar o mês da coluna date. Porque podemos avaliar o motivo das vendas cairem quando surge uma nova loja competindo e 
# aumentando depois de um período porque os clientes se acostumam com as duas lojas próximas e voltam a comprar em ambas.
df1['competition_open_since_month'] = df1.apply( lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] ) 
                                                    else x['competition_open_since_month'], axis=1 )

# competition_open_since_year: ano aproximado que o competidor mais próximo foi aberto
# Se NA é porque não tem um competidor próximo da loja, ou a loja tem um competidor próximo mas não sabe a data que a loja mais próxima 
# foi aberta, uma porque a loja competidora abriu muito antes da loja ser aberta, ou porque abriu depois e alguém esqueceu de anotar.
# regra: se NA pegar o mês da coluna date. Porque podemos avaliar o motivo das vendas cairem quando surge uma nova loja competindo e 
# aumentando depois de um período porque os clientes se acostumam com as duas lojas próximas e voltam a comprar em ambas.
df1['competition_open_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] ) 
                                                    else x['competition_open_since_year'], axis=1 )

# promo2_since_week: descreve a semana do calendário de quando a loja começou a participar da promo2, promo2 é a continuação
# de uma promoção para algumas lojas
# Se NA a loja não aceitou participar da promoção. 
# regra: Vamos substituir NA pela data da coluna date.
df1['promo2_since_week'] = df1.apply( lambda x: x['date'].week if math.isnan(x['promo2_since_week'] ) else x['promo2_since_week'], axis=1 )

# promo2_since_year: descreve o ano de quando a loja começou a participar da promo2, promo2 é a continuação de uma promoção para algumas lojass
# Se NA a loja não aceitou participar da promoção.
# regra: Vamos substituir NA pelo ano data da coluna date.
df1['promo2_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan(x['promo2_since_year'] ) else x['promo2_since_year'], axis=1 )

# promo_interval: quais são os intervalos que a promo2 iniciou, nomeando os meses da promoção.
# regra: Fazer um split dessa coluna e criar uma lista, se a data estiver dentro da lista, criar coluna que a promo2 foi ativa.
month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',7: 'Jul', 8: 'Aug', 9: 'Sept', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

# se NA substituir por 0
df1['promo_interval'].fillna(0, inplace=True )

# pega a date e tranforma a data que é ano, mes e dia, tranforma em data e depois em mês e aplica o month_map, para que os
# numeros sejam substituidos pelas letras
df1['month_map'] = df1['date'].dt.month.map( month_map )

# pegar o promo_interval e fazer um split baseado na virgula, para poder quebrar o array que está separado por virgula em uma lista
# e ai vai ver se o month_map está dentro dessa lista, se sim, retorna 1, senão, retorna 0.
# Se promo_interval igual a 0, retorna zero, senão 1
df1['is_promo'] = df1[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 else 1 
                                                             if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 )

# %% [markdown]
# ## 1.6. Change Types

# %%
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype(int)
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype(int)
df1['promo2_since_week'] = df1['promo2_since_week'].astype(int)
df1['promo2_since_year'] = df1['promo2_since_year'].astype(int)

# %% [markdown]
# ## 1.7. Descriptive Statistical

# %%
num_attributes = df1.select_dtypes(include=['int64', 'float64'])
cat_attributes = df1.select_dtypes(exclude=['int64', 'float64', 'datetime64[ns]'])

# %% [markdown]
# ## 1.7.1. Numerical Attributes

# %%
# Central Tendency - mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# Dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min() )).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew() )).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis() )).T

# concatenate
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']

m
# Out:
#                       attributes     min       max     range         mean  median           std       skew    kurtosis
# 0                          store     1.0    1115.0    1114.0   558.429727   558.0    321.908493  -0.000955   -1.200524
# 1                    day_of_week     1.0       7.0       6.0     3.998341     4.0      1.997390   0.001593   -1.246873
# 2                          sales     0.0   41551.0   41551.0  5773.818972  5744.0   3849.924283   0.641460    1.778375
# 3                      customers     0.0    7388.0    7388.0   633.145946   609.0    464.411506   1.598650    7.091773
# 4                           open     0.0       1.0       1.0     0.830107     1.0      0.375539  -1.758045    1.090723
# 5                          promo     0.0       1.0       1.0     0.381515     0.0      0.485758   0.487838   -1.762018
# 6                 school_holiday     0.0       1.0       1.0     0.178647     0.0      0.383056   1.677842    0.815154
# 7           competition_distance    20.0  200000.0  199980.0  5935.442677  2330.0  12547.646829  10.242344  147.789712
# 8   competition_open_since_month     1.0      12.0      11.0     6.786849     7.0      3.311085  -0.042076   -1.232607
# 9    competition_open_since_year  1900.0    2015.0     115.0  2010.324840  2012.0      5.515591  -7.235657  124.071304
# 10                        promo2     0.0       1.0       1.0     0.500564     1.0      0.500000  -0.002255   -1.999999
# 11             promo2_since_week     1.0      52.0      51.0    23.619033    22.0     14.310057   0.178723   -1.184046
# 12             promo2_since_year  2009.0    2015.0       6.0  2012.793297  2013.0      1.662657  -0.784436   -0.210075
# 13                      is_promo     0.0       1.0       1.0     0.171835     0.0      0.377237   1.739838    1.027039

# %%
sns.distplot(df1['sales'])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
sns.distplot(df1['competition_distance'])
# Out:
# <AxesSubplot:xlabel='competition_distance', ylabel='Density'>

# %% [markdown]
# ## 1.7.2. Categorical Attributes

# %%
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         12
# dtype: int64

# %%
aux1 = df1[(df1['state_holiday'] != '0') & (df1['sales'] > 0)]

# tudo que estiver fora do boxplot são outliers, que são considerados 3 vezes o desvio padrão.

# o feriado B tem uma mediana maior que a do A, mas muito parecida com a C, só que tem um equilibrio entre o número de valores que tem
# entre o quartil 50 até o 75 e do quartil 25 até o 50. No feriado C tem um volume maior de vendas do quartil 50 até o 75. 
plt.subplot(1, 3, 1)
sns.boxplot(x='state_holiday', y='sales', data=aux1)

# O tipo de loja B tem muito mais outiliers que as outras e a mediana de vendas da loja B é muito maior que as outras também.
# E em segundo lugar vem o tipo de loja C, a mediana é maior que a da A e D, porém os dados estão um pouco volumosos em torno da mediana,
# então quer dizer que tem uma concentração maior em torno da mediana. As lojas A e D, tem uma dispersão em torno da mediana mais similar
# entre si, mas uma mediana é diferente da outra.
plt.subplot(1, 3, 2)
sns.boxplot(x='store_type', y='sales', data=aux1)

# Tem mix de produtos muito mais distribuidos no assortment B do que no assortment A, porém no A tem muito mais outliers.
plt.subplot(1, 3, 3)
sns.boxplot(x='assortment', y='sales', data=aux1)
# Out:
# <AxesSubplot:xlabel='assortment', ylabel='sales'>

# %% [markdown]
# # 2.0. PASSO 02 - FEATURE ENGINEERING

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1. Mapa Mental de Hipoteses

# %%
Image('/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/images/MindMapHypothesis.png')

# %% [markdown]
# ### 2.1. Criação das Hipóteses

# %% [markdown]
# #### 2.1.1. Hipóteses Loja

# %% [markdown]
# **1.** Lojas com número maior de funcionários deveriam vender mais.
#
# **2.** Lojas com maior capacidade de estoque deveriam vender mais.
#
# **3.** Lojas com maior porte deveriam vender mais.
#
# **4.** Lojas com maior sortimentos deveriam vender mais.
#
# **5.** Lojas com competidores mais próximos deveriam vender menos.
#
# **6.** Lojas com competidores à mais tempo deveriam vendem mais.

# %% [markdown]
# #### 2.1.2. Hipóteses Produto

# %% [markdown]
# **1.** Lojas que investem mais em Marketing deveriam vender mais.
#
# **2.** Lojas com maior exposição de produto deveriam vender mais.
#
# **3.** Lojas com produtos com preço menor deveriam vender mais.
#
# **5.** Lojas com promoções mais agressivas ( descontos maiores ), deveriam vender mais.
#
# **6.** Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **7.** Lojas com mais dias de promoção deveriam vender mais.
#
# **8.** Lojas com mais promoções consecutivas deveriam vender mais.

# %% [markdown]
# #### 2.1.3. Hipóteses Tempo

# %% [markdown]
# **1.** Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **2.** Lojas deveriam vender mais ao longo dos anos.
#
# **3.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **4.** Lojas deveriam vender mais depois do dia 10 de cada mês.
#
# **5.** Lojas deveriam vender menos aos finais de semana.
#
# **6.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ### 2.2. Lista Final de Hipóteses

# %% [markdown]
# **1.** Lojas com maior sortimentos deveriam vender mais.
#
# **2.** Lojas com competidores mais próximos deveriam vender menos.
#
# **3.** Lojas com competidores à mais tempo deveriam vendem mais.
#
# **4.** Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **5.** Lojas com mais dias de promoção deveriam vender mais.
#
# **6.** Lojas com mais promoções consecutivas deveriam vender mais.
#
# **7.** Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **8.** Lojas deveriam vender mais ao longo dos anos.
#
# **9.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **10.** Lojas deveriam vender mais depois do dia 10 de cada mês.
#
# **11.** Lojas deveriam vender menos aos finais de semana.
#
# **12.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.3. Feature Engineering

# %%
# year
df2['year'] = df2['date'].dt.year

# month
df2['month'] = df2['date'].dt.month

# day
df2['day'] = df2['date'].dt.day

# week of year
df2['week_of_year'] = df2['date'].dt.isocalendar().week

# year week
df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

# competion since
df2['competition_since'] = df2.apply(lambda x: datetime.datetime(year = x['competition_open_since_year'], month=x['competition_open_since_month'], day=1), axis=1)
df2['competition_time_month'] = ((df2['date'] - df2['competition_since']) / 30).apply( lambda x: x.days).astype(int)

# promo since
df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )

df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta( days=7 ) )

df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply(lambda x: x.days ).astype( int )

# assortment
df2['assortment'] = df2['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )

# state holiday
df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' 
                                                  if x == 'b' else 'christmas' if x == 'c' else 'regular_day' )

# %%
df2.sample(5)
# Out:
#         store  day_of_week       date  sales  customers  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year    promo_interval month_map  is_promo  year  month  day  week_of_year year_week competition_since  competition_time_month promo_since  promo_time_week
# 95908      19            3 2015-05-06   7878        711     1      1   regular_day               0          a   extended                3240.0                             5                         2015       1                 22               2011  Mar,Jun,Sept,Dec       May         0  2015      5    6            19   2015-18        2015-05-01                       0  2011-05-23              206
# 934612   1028            6 2013-03-16   2273        310     1      0   regular_day               0          a      basic                 150.0                             3                         2013       1                 31               2013   Jan,Apr,Jul,Oct       Mar         0  2013      3   16            11   2013-10        2013-03-01                       0  2013-07-29              -20
# 832480    361            6 2013-06-15   5674        606     1      0   regular_day               0          c   extended                4490.0                             5                         2014       1                  5               2013   Feb,May,Aug,Nov       Jun         0  2013      6   15            24   2013-23        2014-05-01                     -11  2013-01-28               19
# 94033     374            5 2015-05-08   7544        917     1      1   regular_day               0          a      basic                1150.0                             9                         2007       0                 19               2015                 0       May         0  2015      5    8            19   2015-18        2007-09-01                      93  2015-05-04                0
# 745779    630            7 2013-09-01      0          0     0      0   regular_day               0          a      basic                1690.0                             4                         2015       0                 35               2013                 0      Sept         0  2013      9    1            35   2013-34        2015-04-01                     -20  2013-08-26                0

# %% [markdown]
# # 3.0. PASSO 03 - FILTRAGEM DE VARIÁVEIS

# %%
df3 = df2.copy()

# %%
df3.head()
# Out:
#    store  day_of_week       date  sales  customers  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year   promo_interval month_map  is_promo  year  month  day  week_of_year year_week competition_since  competition_time_month promo_since  promo_time_week
# 0      1            5 2015-07-31   5263        555     1      1   regular_day               1          c      basic                1270.0                             9                         2008       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2008-09-01                      84  2015-07-27                0
# 1      2            5 2015-07-31   6064        625     1      1   regular_day               1          a      basic                 570.0                            11                         2007       1                 13               2010  Jan,Apr,Jul,Oct       Jul         1  2015      7   31            31   2015-30        2007-11-01                      94  2010-03-22              279
# 2      3            5 2015-07-31   8314        821     1      1   regular_day               1          a      basic               14130.0                            12                         2006       1                 14               2011  Jan,Apr,Jul,Oct       Jul         1  2015      7   31            31   2015-30        2006-12-01                     105  2011-03-28              226
# 3      4            5 2015-07-31  13995       1498     1      1   regular_day               1          c   extended                 620.0                             9                         2009       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2009-09-01                      71  2015-07-27                0
# 4      5            5 2015-07-31   4822        559     1      1   regular_day               1          a      basic               29910.0                             4                         2015       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2015-04-01                       4  2015-07-27                0

# %% [markdown]
# ## 3.1. Filtragem das Linhas

# %%
# Filtrar linhas de lojas abertas somente e sales maior que 0.
df3 = df3[(df3['open'] != 0) & (df2['sales'] > 0)]

# %% [markdown]
# ## 3.2. Seleção das Colunas

# %%
# Dropar colunas costumers, open (uma vez que filtramos todas as linhas onde o open é diferente de 0, todas as linhas que 
# sobraram são open igual a 1, então a coluna open é só 1, e não ter variabilidade de nada). 
# As colunas, promo_interval, derivamos variaveis (is_promo).
# E a coluna month_map que usamos como auxiliar. 
cols_drop = ['customers', 'open', 'promo_interval', 'month_map']
df3 = df3.drop(cols_drop, axis=1)

# %% [markdown]
# # 4.0. PASSO 04 - ANALISE EXPLORATORIA DOS DADOS

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1. Análise Univariada
# Objetivo: Olhar unicamente para todas as variáveis.

# %% [markdown]
# ### 4.1.1. Response Variable

# %%
sns.distplot(df4['sales'])
# Tem kurtosi, tem uma skill mais para a esquerda, então é positiva, mas não está centrada.
# Quanto mais normal for a variável resposta, melhor o algoritmo vai performar.
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# ### 4.1.2. Numerical Variable

# %%
num_attributes.hist(bins=25);

# %% [markdown]
# Insights:
# - competition_distance: concentração maior na distância dos competidores menor, todos os competidores estão muito próximos.
# - competition_open_since_month (distância que o competidor abriu em meses): tem um pico nos competidores que abriram 4 meses atrás. Depois cai um pouco e sobe de novo no 7º mês.
# - day_of_week: não importa o dia da semana, vende igual em todos eles. Não tem um comportamento, sozinha se não for comparada com nada, não tem informação relevante para o aprendizado do modelo.
# - is_promo: tem muito mais vendas quando não tem promoção. Quando tem promoção tem menos linhas de vendas.
# - promo2_since_year: número de vendas vai aumentando, em 2013 tem um pico. 2014 caiu um pouco e 2015 volta mais ou menos para as vendas antes de 2013.
# - customers: temos mais vendas quando customers estão próximos a 300 mil.

# %% [markdown]
# ### 4.1.3. Categorical Variable

# %%
# state_holiday
plt.subplot( 3, 2, 1 )
a = df4[df4['state_holiday'] != 'regular_day']
sns.countplot( a['state_holiday'] )
plt.subplot( 3, 2, 2 )
sns.kdeplot( df4[df4['state_holiday'] == 'public_holiday']['sales'],label='public_holiday', shade=True )
sns.kdeplot( df4[df4['state_holiday'] == 'easter_holiday']['sales'],label='easter_holiday', shade=True )
sns.kdeplot( df4[df4['state_holiday'] == 'christmas']['sales'],label='christmas', shade=True )

# store_type
plt.subplot( 3, 2, 3 )
sns.countplot( df4['store_type'] )
plt.subplot( 3, 2, 4 )
sns.kdeplot( df4[df4['store_type'] == 'a']['sales'], label='a', shade=True )
sns.kdeplot( df4[df4['store_type'] == 'b']['sales'], label='b', shade=True )
sns.kdeplot( df4[df4['store_type'] == 'c']['sales'], label='c', shade=True )
sns.kdeplot( df4[df4['store_type'] == 'd']['sales'], label='d', shade=True )

# assortment
plt.subplot( 3, 2, 5 )
sns.countplot( df4['assortment'] )
plt.subplot( 3, 2, 6 )
sns.kdeplot( df4[df4['assortment'] == 'extended']['sales'], label='extended',shade=True )
sns.kdeplot( df4[df4['assortment'] == 'basic']['sales'], label='basic',shade=True )
sns.kdeplot( df4[df4['assortment'] == 'extra']['sales'], label='extra',shade=True )
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# Insights:
# - Public_holiday tem um volume muito maior de vendas, então ele tem um pico muito maior. Christmas tem um volume menor mas tem um pico muito maior que o easter_holiday.
# - O tipo de loja A tem um volume de vendas muito maior, mas não tem um pico tão grande. Enquanto lojas do tipo B tem uma alta concentração.
# - Tipos de assortment que vendem mais é o básico, depois o extended e o extra vende pouco. Já o extra tem um pico menor mas tem uma distribuição maior. Então temos mais lojas com diferentes tipos de extras, tem lojas que vendem mais com o assortment extra, lojas que vendem menos com assortment extra.

# %% [markdown]
# ## 4.2. Análise Bivariada
# Objetivo: Encontrar o impacto de uma variável em relação a variável resposta.

# %%
# Média de vendas total
df4['sales'].mean()
# Out:
# 6955.959133664481

# %% [markdown]
# ### H1. Lojas com maior sortimentos deveriam vender mais.
# **VERDADEIRA**: Na média, lojas com MAIOR SORTIMENTO vendem MAIS.

# %%
# Estratégia: pegar a média de vendas por assortment.

# Gráfico de média de vendas por assortment.
aux1 = df4[['assortment', 'sales']].groupby('assortment').mean().reset_index()
sns.barplot(x='assortment', y='sales', data=aux1);
plt.axhline(6955, 0, 1, color='black');

# Gráfico de linhas por assortment para comparar semana a semana.
aux2 = df4[['year_week', 'assortment', 'sales']].groupby(['year_week','assortment']).mean().reset_index()
aux2.pivot(index='year_week', columns='assortment', values='sales').plot();

# aux3 = aux2[aux2['assortment'] == 'extra']
# aux3.pivot(index='year_week', columns='assortment', values='sales').plot()

# %% [markdown]
# ### H2. Lojas com competidores mais próximos deveriam vender menos.
# **FALSA**: Lojas com competidores mais próximos entre 0 a 2000 metros, vendem acima da média de vendas que é 6955.

# %%
aux1 = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()

# Gráfico de dispersão com total de vendas por grupos de distância de lojas
plt.subplot(1,3,1)
sns.scatterplot(x='competition_distance', y='sales', data=aux1);

plt.subplot(1,3,2)
bins = list(np.arange(0,20000, 1000))
# Total de vendas por grupos de distância de lojas
aux1['competition_distance_binned'] = pd.cut(aux1['competition_distance'], bins=bins)
aux2 = aux1[['competition_distance_binned', 'sales']].groupby('competition_distance_binned').sum().reset_index()
sns.barplot(x='competition_distance_binned', y='sales', data=aux2);
plt.xticks(rotation=90);

# Gráfico que mede a força da correlação entre a competition_distance e as vendas
# -0.23 significa que quanto mais distante o meu conconcorrente está, menor a venda.
plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %%
# Total de lojas por grupos de distância de lojas
aux3 = df4[['competition_distance', 'store']].groupby('competition_distance').count().reset_index()

aux3['competition_distance_binned'] = pd.cut(aux3['competition_distance'], bins=bins)
aux4 = aux3[['competition_distance_binned', 'store']].groupby('competition_distance_binned').sum().reset_index()

sns.barplot(x='competition_distance_binned', y='store', data=aux4);

# %%
# Média de vendas por grupo de distância de lojas
df_mean = df4[['competition_distance', 'sales']].groupby('competition_distance').mean().reset_index()

df_mean['competition_distance_binned'] = pd.cut(df_mean['competition_distance'], bins=bins)
aux5 = df_mean[['competition_distance_binned', 'sales']].groupby('competition_distance_binned').mean().reset_index()

sns.barplot(x='competition_distance_binned', y='sales', data=aux5);
plt.axhline(6955, 0, 1, color='black');

# %% [markdown]
# ### H3. Lojas com competidores à mais tempo deveriam vender mais.
# **FALSA**: Lojas com competidores à mais tempo vendem menos que a média de vendas que é de 6955.

# %%
# Valores negativos são referentes a vendas que aconteceram antes da competição entrar em vigor.
# Valores positivos são referentes a vendas que aconteceram depois da competição entrar em vigor.

# Total de vendas por meses de competição
plt.subplot(2,1,1)
aux1 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()
aux2 = aux1[(aux1['competition_time_month'] < 120) & (aux1['competition_time_month'] != 0)] # 120 primeiros meses de competição e não competiram no mesmo mês da venda
sns.barplot(x='competition_time_month', y='sales', data=aux2);
plt.xticks(rotation=90);

# Gráfico que mede comportamento e tendência
plt.subplot(2,2,3)
sns.regplot(x='competition_time_month', y='sales', data=aux2);

# Gráfico que mede a força da correlação entre a competition_time_month e as vendas
# O tempo que o competidor começou em meses em relação a variável resposta é -0.1. 
plt.subplot(2,2,4)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %%
# Total de lojas por meses de competição
aux_count = df4[['competition_time_month', 'store']].groupby('competition_time_month').count().reset_index()
aux3 = aux_count[(aux_count['competition_time_month'] < 120) & (aux_count['competition_time_month'] != 0)] # 120 primeiros meses de competição e não competiram no mesmo mês da venda
sns.barplot(x='competition_time_month', y='store', data=aux3);
plt.xticks(rotation=90);

# %%
# Média de vendas de lojas por meses de competição
aux_mean = df4[['competition_time_month', 'sales']].groupby('competition_time_month').mean().reset_index()
aux4 = aux_mean[(aux_mean['competition_time_month'] < 120) & (aux_mean['competition_time_month'] != 0)] # 120 primeiros meses de competição e não competiram no mesmo mês da venda
sns.barplot(x='competition_time_month', y='sales', data=aux4);
plt.axhline(6955.95, 0, 1, color='black')
plt.xticks(rotation=90);

# %% [markdown]
# ### H4. Lojas com promoções ativas por mais tempo deveriam vender mais.
# **VERDADEIRO**: Lojas com promoções ativas por mais tempo vendem mais, depois de um certo período de promoção. Muitas lojas ficaram acima da média de vendas de 6955.

# %%
# Estratégia: pegar a média de vendas da promo_time_week, que indica:
# Valores negativos são referentes a vendas que aconteceram antes da promoção entrar em vigor.
# Valores positivos são referentes a vendas que aconteceram depois da promoção entrar em vigor.

aux1 = df4[['promo_time_week', 'sales']].groupby('promo_time_week').mean().reset_index()

# Gráfico de média de vendas de promoção extendida
plt.subplot(2,1,1)
aux2 = aux1[aux1['promo_time_week'] > 0] # promo extendido
sns.barplot(x='promo_time_week', y='sales', data=aux2);
plt.title('Média de vendas de promoção extendida');
plt.axhline(6955.95, 0, 1, color='black')
plt.xticks(rotation=90);

# Gráfico de média de vendas de promoção regular
plt.subplot(2,1,2)
aux3 = aux1[aux1['promo_time_week'] < 0] # promo regular
sns.barplot(x='promo_time_week', y='sales', data=aux3);
plt.title('Média de vendas de promoção regular');
plt.axhline(6955.95, 0, 1, color='black')
plt.xticks(rotation=90);

# %%
# Gráfico de dispersão
plt.subplot(2,2,1)
sns.regplot(x='promo_time_week', y='sales', data=aux2);
plt.title('Promoção extendida');

# Gráfico de dispersão
plt.subplot(2,2,2)
sns.regplot(x='promo_time_week', y='sales', data=aux3);
plt.title('Promoção regular');

# Gráfico que mede a força da correlação
plt.subplot(2,2,3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### <s>H5. Lojas com mais dias de promoção deveriam vender mais.</s>

# %% [markdown]
# ### H6. Lojas com mais promoções consecutivas deveriam vender mais.
# **FALSA**: Lojas com mais promoções consecutivas vendem menos do que lojas que participam apenas da promoção tradicional (1ª promoção).

# %%
# Estratégia: 
# Pegar a promo que indica que a loja está no período tradicional de promoções.
# Pegar a promo2 que indica que a loja está participando da promoção extendida.
# E pegar as médias de vendas.

df4[['promo', 'promo2', 'sales']].groupby(['promo', 'promo2']).mean().sort_values('sales', ascending=False).reset_index()
# Out:
#    promo  promo2        sales
# 0      1       0  8618.452062
# 1      1       1  7836.672987
# 2      0       0  6328.187633
# 3      0       1  5529.566684

# %%
# Gráfico de média de vendas por promoção 'Tradicional & Extendida', 'Tradicional'.
aux1 = df4[(df4['promo'] == 1) & (df4['promo2'] == 1)][['year_week', 'sales']].groupby('year_week').mean().reset_index()
ax = aux1.plot()

aux2 = df4[(df4['promo'] == 1) & (df4['promo2'] == 0)][['year_week', 'sales']].groupby('year_week').mean().reset_index()
aux2.plot(ax=ax)

ax.legend(labels=['Tradicional & Extendida', 'Tradicional']);

# %% [markdown]
# ### H7. Lojas abertas durante o feriado de Natal deveriam vender mais.
# **FALSA**: Lojas abertas durante o feriado de Natal na média vendem mais que os feriados públicos e dias normais, mas vedem menos que o feriado da Páscoa. Somente em 2014 que as lojas venderam mais no feriado de Natal.

# %%
# Estrategia: pegar a média de vendas por state_holiday.
plt.subplot(1,2,1) 
aux1 = df4[['state_holiday', 'sales']].groupby('state_holiday').mean().sort_values('sales', ascending=False).reset_index()
sns.barplot(x='state_holiday', y='sales', data=aux1)

# Grafico de média de vendas por state_holiday por anos.
plt.subplot(1,2,2)
aux2 = df4[['year', 'state_holiday', 'sales']].groupby(['year', 'state_holiday']).mean().reset_index()
sns.barplot(x='year', y='sales', hue='state_holiday', data=aux2);

# %% [markdown]
# ### H8. Lojas deveriam vender mais ao longo dos anos.
# **FALSA**: Lojas vendem menos ao longo dos anos.

# %%
aux1 = df4[['year', 'sales']].groupby('year').sum().reset_index()

# Gráfico de total de vendas por ano
plt.subplot(1,3,1)
sns.barplot(x='year', y='sales', data=aux1);

# Tendência e força da correlação
plt.subplot(1,3,2)
sns.regplot(x='year', y='sales', data=aux1);

plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# -0.92 de correlação = conforme os anos vão avançando as vendas vão caindo. 
# Isso é pelo fato do ano de 2015 não estar completo ainda. Quando os anos não estão completos ele puxa pra baixo a correlação

# %% [markdown]
# ### H9. Lojas deveriam vender mais no segundo semestre do ano.
# **FALSA**: Lojas vendem menos no segundo semestre do ano.

# %%
aux1 = df4[['month', 'sales']].groupby('month').sum().reset_index()

# Gráfico de total de vendas por meses
plt.subplot(1, 3, 1)
sns.barplot(x='month', y='sales', data=aux1);

# Tendência e força da correlação
plt.subplot(1, 3, 2)
sns.regplot(x='month', y='sales', data=aux1);

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### H10. Lojas deveriam vender mais depois do dia 10 de cada mês.
# **VERDADEIRO**: Lojas vendem mais depois do dia 10 de cada mes. Pelo fato de ter mais dias no mês, 20 dias contra 10.
#
# As vendas são maiores antes do dia 10 quando olhamos para as médias de vendas pelos grupos: "Antes do dia 10" & "Depois do dia 10".

# %%
aux1 = df4[['day', 'sales']].groupby('day').sum().reset_index()

# Gráfico de vendas por dia
plt.subplot(2, 2, 1)
sns.barplot(x='day', y='sales', data=aux1);

# Tendência e força da correlação
plt.subplot(2, 2, 2)
sns.regplot(x='day', y='sales', data=aux1);

plt.subplot(2, 2, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

aux1['before_after'] = aux1['day'].apply( lambda x: 'before_10_days' if x <= 10 else 'after_10_days')
aux2 =aux1[['before_after', 'sales']].groupby('before_after').sum().reset_index()

plt.subplot(2, 2, 4)
sns.barplot(x='before_after', y='sales', data=aux2);

# %%
# Média de vendas por agrupados de dias: "Antes do dia 10" & "Depois do dia 10"
aux1 = df4[['day', 'sales']].groupby('day').sum().reset_index()

aux1['before_after'] = aux1['day'].apply( lambda x: 'before_10_days' if x <= 10 else 'after_10_days')
aux3 = aux1[['before_after', 'sales']].groupby('before_after').mean().reset_index()
sns.barplot(x='before_after', y='sales', data=aux3);

# %% [markdown]
# ### H11. Lojas deveriam vender menos aos finais de semana.
# **VERDADEIRA**: Lojas vendem menos nos finais de semana.

# %%
# Gráfico de vendas por dia da semana
aux1 = df4[['day_of_week', 'sales']].groupby('day_of_week').sum().reset_index()

plt.subplot(1, 3, 1)
sns.barplot(x='day_of_week', y='sales', data=aux1);

plt.subplot(1, 3, 2)
sns.regplot(x='day_of_week', y='sales', data=aux1);

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### H12. Lojas deveriam vender menos durante os feriados escolares.
# **FALSA**: Na média de vendas, os feriados escolares vendem mais do que os dias normais. Vendendo menos apenas no mês de Dezembro.

# %%
# Gráfico de média de vendas de feriado escolar e dias normais.
aux1 = df4[['school_holiday', 'sales']].groupby('school_holiday').mean().reset_index()

plt.subplot(2, 1, 1)
sns.barplot( x='school_holiday', y='sales', data=aux1 );

aux2 = df4[['month', 'school_holiday', 'sales']].groupby(['month','school_holiday']).mean().reset_index()

plt.subplot(2, 1, 2)
sns.barplot(x='month', y='sales', hue='school_holiday', data=aux2);

# %% [markdown]
# ### 4.2.1. Resumo das Hipóteses

# %%
tab =[['Hipoteses', 'Conclusao', 'Relevancia'],

['H1', 'Verdadeira', 'Baixa'],
['H2', 'Falsa', 'Media'],
['H3', 'Falsa', 'Media'],
['H4', 'Verdadeiro', 'Baixa'],
['H5', '-', '-'],
['H6', 'Falsa', 'Baixa'],
['H7', 'Falsa', 'Media'],
['H8', 'Falsa', 'Alta'],
['H9', 'Falsa', 'Alta'],
['H10', 'Verdadeira', 'Alta'],
['H11', 'Verdadeira', 'Alta'],
['H12', 'Falsa', 'Alta'],
]
print( tabulate( tab, headers='firstrow' ) )
# Out:
# Hipoteses    Conclusao    Relevancia
# -----------  -----------  ------------
# H1           Verdadeira   Baixa
# H2           Falsa        Media
# H3           Falsa        Media
# H4           Verdadeiro   Baixa
# H5           -            -
# H6           Falsa        Baixa
# H7           Falsa        Media
# H8           Falsa        Alta
# H9           Falsa        Alta
# H10          Verdadeira   Alta
# H11          Verdadeira   Alta
# H12          Falsa        Alta

# %% [markdown]
# ## 4.3. Análise Multivariada
# Objetivo: Encontrar não só as correlações ou o impacto entre a variável e a variável resposta, mas as correlações entre as próprias variáveis.

# %% [markdown]
# ### 4.3.1. Numerical Attributes

# %%
# Método corr = pearson: faz a correlação entre todas as variáveis númericas. Vai de -1 até 1.
# Gráfico de correlação: Quanto mais perto da cor preto, maior é a correlação negativa.
# Quanto mais perto da cor branca, maior é a correlação positiva.
# Devemos olhar os mais claros e mais escuros, o que tá no meio não é tão importante.
# A correlação entre duas variáveis que são a mesma é 1, porque estamos correlaciondo as mesmas variáveis. 

correlation = num_attributes.corr(method='pearson')
sns.heatmap( correlation, annot=True );

# %% [markdown]
# ### 4.3.2. Categorical Attributes

# %%
# Método Cramer V: para fazer a correlação entre todas as variáveis categóricas. Vai de 0 até 1, então não tem uma correlação negativa
# entre variáveis categóricas, é só uma correlação positiva ou nenhuma correlação. Quanto mais perto do 0 menor a correlação, 
# quanto mais perto do 1 maior a correlação.

# Matriz de confusão ou tabela de contingência: faz todas as possíveis combinações entre as variáveis categóricas e conta o número de 
# linhas daquelas combinações.

# Only categorical data
a = df4.select_dtypes(include='object')

# Calculate cramer V
a1 = cramer_v(a['state_holiday'], a['state_holiday'])
a2 = cramer_v(a['state_holiday'], a['store_type'])
a3 = cramer_v(a['state_holiday'], a['assortment'])

a4 = cramer_v(a['store_type'], a['state_holiday'])
a5 = cramer_v(a['store_type'], a['store_type'])
a6 = cramer_v(a['store_type'], a['assortment'])

a7 = cramer_v(a['assortment'], a['state_holiday'])
a8 = cramer_v(a['assortment'], a['store_type'])
a9 = cramer_v(a['assortment'], a['assortment'])

# Final dataset
d = pd.DataFrame({'state_holiday': [a1, a2, a3],
                  'store_type': [a4, a5, a6],
                  'assortment': [a7, a8, a9]
                 })

d = d.set_index(d.columns)
sns.heatmap(d, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5.0. PASSO 05 - PREPARAÇÃO DOS DADOS

# %% [markdown]
# Encoding:
# - Trazer as variáveis categóricas para numéricas. Para que os algoritmos de Machine Learning consigam usar essas variáveis para aprender.
#
# Normalização das escalas:
# - Mudar a escala, para que todo mundo fique no mesmo range.
# - Rescala o centro para 0 com desvio-padrão igual a 1.
# - Funciona muito bem para variáveis que possui uma distribuição normal
# - Fórmula de Normalização: Pegar todos os valores da coluna de variável e calcular a média, depois calcular o desvio padrão. Depois pegar o primeiro valor da coluna, subtrair a média e dividir pelo desvio padrão, o resultado desse cálculo vai ser o novo valor. Então vamos trazer o valor antigo para uma nova escala que é o resultado dessa conta.
#
# Rescaling:
# - Rescala para o intervalo entre 0 e 1.
# - Distribuições não Gaussianas (não possui uma distribuição normal).
# - Funciona muito bem para variáveis que NÃO possui uma distribuição normal
# - Fórmula de Min-Max Scaler: Pegar a coluna de variável numérica onde vamos aplicar a fórmula, encontrar a média da coluna, encontrar o valor máximo e o valor mínimo da coluna, depois fazer a diferença entre o máximo e o mínimo (que é o range) e vai guardar esse valor, e ai pra cada valor original dessa variável, vamos subtrair a média e dividir pelo range. O resultado dessa conta vai se o novo valor em uma nova escala. E ai vamos gerar uma nova coluna com esses novos valores na nova escala. Essa fórmula é super sensível para outliers.
# - Fórmula de Robust Scaler (tira a dependência do outilier): Pegar a coluna de variável numérica onde vamos aplicar a fórmula, encontrar a média da coluna, encontrar o valor do quartil 3 e o valor do quartil 1 da coluna, depois fazer a diferença entre o quartil 3 e o quartil 1 (que é o range) e vai guardar esse valor, e ai pra cada valor original dessa variável, vamos subtrair a média e dividir pelo range. O resultado dessa conta vai se o novo valor em uma nova escala. E ai vamos gerar uma nova coluna com esses novos valores na nova escala.
#
# Transformação:
# - Conversão de Features Categóricas para Numéricas (Encoding).
# - Transformação de Natureza: Por exemplo, os meses é uma variável cíclica, pois dentro de cada ano tem o mesmo conjunto de meses, indo do 1 ao 12. Existe uma forma de transformar para cíclico para que o modelo entenda essa natureza cíclica.

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1. Normalização

# %% [markdown]
# ## 5.2. Rescaling

# %%
# Selecionar somente as colunas com variáveis numéricas
a = df5.select_dtypes(include=['int64', 'float64'])
a.head()
# Out:
#    store  day_of_week  sales  promo  school_holiday  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  month  day  competition_time_month  promo_time_week
# 0      1            5   5263      1               1                1270.0                             9                         2008       0                 31               2015         0  2015      7   31                      84                0
# 1      2            5   6064      1               1                 570.0                            11                         2007       1                 13               2010         1  2015      7   31                      94              279
# 2      3            5   8314      1               1               14130.0                            12                         2006       1                 14               2011         1  2015      7   31                     105              226
# 3      4            5  13995      1               1                 620.0                             9                         2009       0                 31               2015         0  2015      7   31                      71                0
# 4      5            5   4822      1               1               29910.0                             4                         2015       0                 31               2015         0  2015      7   31                       4                0

# %%
# Utilizar o boxplot para ver se tem outiliers
plt.subplot(2,2,1)
sns.boxplot(df5['competition_distance']);

plt.subplot(2,2,2)
sns.boxplot(df5['competition_time_month']);

# %%
rs = RobustScaler()
mms = MinMaxScaler()

# RobustScaler
# competition distance
# metodo = fit_transform: encontra os parâmetros da fórmula e já aplica nos dados, os parâmetros da robust scaler são os quartis,
# quartil 1 e quartil 3. Então o fit_transform encontra o quartil 1 e quartil 3 da coluna e já aplica a fórmula.
df5['competition_distance'] = rs.fit_transform(df5[['competition_distance']].values)
#pickle.dump(rs, open('parameter/competition_distance_scaler.pkl', 'wb'))

# competition time month
df5['competition_time_month'] = rs.fit_transform(df5[['competition_time_month']].values)
#pickle.dump(rs, open('parameter/competition_time_month_scaler.pkl', 'wb'))


# MinMaxScaler
# promo time week
df5['promo_time_week'] = mms.fit_transform( df5[['promo_time_week']].values)
#pickle.dump(rs, open( 'parameter/promo_time_week_scaler.pkl', 'wb'))

# year
df5['year'] = mms.fit_transform( df5[['year']].values)
#pickle.dump(mms, open('parameter/year_scaler.pkl', 'wb'))

# %% [markdown]
# ## 5.3. Tranformação

# %% [markdown]
# ### 5.3.1. Encoding

# %%
# Separar as variáveis que tem natureza cíclica
# state_holiday - One Hot Encoding: get_dummies
df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

# store_type - Label Encoding
le = LabelEncoder()
df5['store_type'] = le.fit_transform( df5['store_type'])
#pickle.dump(le, open('parameter/store_type_scaler.pkl', 'wb'))

# assortment - Ordinal Encoding
assortment_dict = {'basic': 1, 'extra': 2, 'extended': 3}
df5['assortment'] = df5['assortment'].map(assortment_dict)

# %% [markdown]
# ### 5.3.2. Response Variable Transformation

# %%
# Logarithm Transformation: Tranformar a variável resposta, usar o logarítmo log1p na variável sales
df5['sales'] = np.log1p(df5['sales'])

# %% [markdown]
# ### 5.3.3. Nature Transformation

# %%
# Pegar a variável (day of week, month...), transformar em duas variáveis seno e cosseno que combinadas vão representar a natureza cíclica

# day of week
# pi dividido pelo tamanho do ciclo, no caso de dias de semana, são 7
df5['day_of_week_sin'] = df5['day_of_week'].apply(lambda x: np.sin(x * (2. * np.pi/7)))
df5['day_of_week_cos'] = df5['day_of_week'].apply(lambda x: np.cos(x * (2. * np.pi/7)))

# month
# pi dividido pelo tamanho do ciclo, no caso de meses, são 12
df5['month_sin'] = df5['month'].apply(lambda x: np.sin(x * (2. * np.pi/12))) 
df5['month_cos'] = df5['month'].apply(lambda x: np.cos(x * (2. * np.pi/12)))

# day
# pi dividido pelo tamanho do ciclo, no caso de dias, são 30
df5['day_sin'] = df5['day'].apply(lambda x: np.sin(x * (2. * np.pi/30))) 
df5['day_cos'] = df5['day'].apply(lambda x: np.cos(x * (2. * np.pi/30)))

# week of year
# pi dividido pelo tamanho do ciclo, no caso de semanas, são 52
df5['week_of_year_sin'] = df5['week_of_year'].apply(lambda x: np.sin(x * (2. * np.pi/52))) 
df5['week_of_year_cos'] = df5['week_of_year'].apply(lambda x: np.cos(x * (2. * np.pi/52)))

# %% [markdown]
# # 6.0. PASSO 06 - FEATURE SELECTION

# %%
df6 = df5.copy()

# %% [markdown]
# ## 6.1. Split dataframe into training and test dataset

# %%
# Excluir as colunas originais, pois derivamos novas variáveis na Feature Engineering. Exemplo a week_of_year sin e cos.
cols_drop = ['week_of_year', 'day', 'month', 'day_of_week', 'promo_since','competition_since', 'year_week']
df6 = df6.drop(cols_drop, axis=1)

# %%
# Pegar a data mínima de vendas e máxima de vendas
#df6[['store', 'date']].groupby('store').max().reset_index()

# Pegar a data de 6 semanas antes do max date acima 
#df6[['store', 'date']].groupby('store').max().reset_index()['date'][0] - datetime.timedelta(days = 6*7)

# %%
# training dataset: pegar dados anteriores a data 19-06-2015
X_train = df6[df6['date'] < '2015-06-19']
y_train = X_train['sales']

# test dataset: pegar dados posteriores ou igual a data 19-06-2015
X_test = df6[df6['date'] >= '2015-06-19']
y_test = X_test['sales']

print('Training Min Date: {}'.format(X_train['date'].min()))
print('Training Max Date: {}'.format(X_train['date'].max()))
print('\nTest Min Date: {}'.format(X_test['date'].min()))
print('Test Max Date: {}'.format(X_test['date'].max()))
# Out:
# Training Min Date: 2013-01-01 00:00:00
# Training Max Date: 2015-06-18 00:00:00
#
# Test Min Date: 2015-06-19 00:00:00
# Test Max Date: 2015-07-31 00:00:00

# %% [markdown]
# ## 6.2. Boruta as Feature Selector
# Iteration: 	9 / 100 = Número da Iteração.
#
# Confirmed: 	18 = Quantas variáveis o boruta já confirmou como sendo relevantes para o modelo.
#
# Tentative: 	0 = São variáveis que o boruta teve dúvida, ele não conseguiu nessa iteração classificá-las como sendo irrelevantes ou não.
#
# Rejected: 	9 = São variáveis que o boruta já rejeitou e considerou como não sendo relevantes para o modelo.

# %%
# # training and test dataset for Boruta
# # dropar as colunas date e sales pois é o conjunto de treino
# X_train_n = X_train.drop(['date', 'sales'], axis=1).values
# # ravel = coloca tudo dentro de um vetor
# y_train_n = y_train.values.ravel()

# # define RandomForestRegressor
# # n_jobs=-1 = usa todos os cores da máquina e faz o processamento paralelo, criando as árvores em paralelo
# rf = RandomForestRegressor(n_jobs=-1)

# # define Boruta
# # rf = random forest, n_estimator = auto = o modelo define o melhor número de ramificações, verbose = 2 = para ver os prints do algoritmo, 
# # random_state = 42 = toda vez que ele selecionar uma variável aleatória, cravamos o início dele em 42 e parta do mesmo ínicio
# boruta = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42).fit(X_train_n, y_train_n)

# %% [markdown]
# ### 6.2.1. Best Features from Boruta

# %%
cols_selected = boruta.support_.tolist()

# best features: o boruta rankeia as colunas como sendo relevantes
# Como não podemos mais usar o X_train_n porque ele virou um vetor, criamos a X_train_fs com a X_train dropando date e sales
X_train_fs = X_train.drop(['date', 'sales'], axis=1)
cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()

# not selected boruta: ver as colunas que o boruta não selecionou, vamos ver o que tem na X_train_fs que não tem nas que ele selecinou 
cols_not_selected_boruta = list(np.setdiff1d(X_train_fs.columns,cols_selected_boruta))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-7e5306b4cc1e> in <module>
# ----> 1 cols_selected = boruta.support_.tolist()
#       2
#       3 # best features: o boruta rankeia as colunas como sendo relevantes
#       4 # Como não podemos mais usar o X_train_n porque ele virou um vetor, criamos a X_train_fs com a X_train dropando date e sales
#       5 X_train_fs = X_train.drop(['date', 'sales'], axis=1)
#
# NameError: name 'boruta' is not defined

# %%
# Colunas relevantes para o modelo
#cols_selected_boruta

# %%
# Colunas não relevantes para o modelo
#cols_not_selected_boruta

# %% [markdown]
# ## 6.3. Manual Feature Selection

# %%
cols_selected_boruta = [
'store',
'promo',
'store_type',
'assortment',
'competition_distance',
'competition_open_since_month',
'competition_open_since_year',
'promo2',
'promo2_since_week',
'promo2_since_year',
'competition_time_month',
'promo_time_week',
'day_of_week_sin',
'day_of_week_cos',
'month_sin',
'month_cos',
'day_sin',
'day_cos',
'week_of_year_sin',
'week_of_year_cos']

# columns to add
feat_to_add = ['date', 'sales']
cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend(feat_to_add)

# %% [markdown]
# # 7.0. PASSO 07 - MACHINE LEARNING MODELLING

# %% [markdown]
# 3 tipos de erros:
# - MAE:
#
# - MAPE:
#
# - RMSE:

# %%
# Selecionar as colunas mais relevantes segundo o boruta
x_train = X_train[cols_selected_boruta]
x_test = X_test[cols_selected_boruta]

# Time Series Data Preparation
x_training = X_train[cols_selected_boruta_full]

# %% [markdown]
# ## 7.1. Average Model (Modelo de Média)
# O principal papel do modelo de média é ser uma base comparativa para a perfomance dos outros modelos.

# %%
aux1 = x_test.copy()
aux1['sales'] = y_test.copy() # criar variável sales no aux1 e copiar essa variável para y_test

# prediction
aux2 = aux1[['store', 'sales']].groupby('store').mean().reset_index().rename(columns={'sales': 'predictions'})
aux1 = pd.merge(aux1, aux2, how='left', on='store') # join com o conjunto original
yhat_baseline = aux1['predictions']

# performance
baseline_result = ml_error('Average Model', np.expm1(y_test), np.expm1(yhat_baseline)) # expm1 = exponencial para voltar o log no valor original
baseline_result
# Out:
#       Model Name          MAE    MAPE         RMSE
# 0  Average Model  1354.800353  0.2064  1835.135542

# %% [markdown]
# ## 7.2. Linear Regression Model (Modelo de Regressão Linear)
# Usamos algoritmos lineares, que são algoritmos mais simples, se o modelos lineares eles tiverem uma boa performance, podemos assumir que o conjunto de dados tem um comportamento linear. Agora se os modelos lineares tiverem uma performance muito ruim, significa que o conjunto de dados ou o fenômeno que estamos tentando modelar é complexo, então precisamos de algoritmos não lineares como redes neurais, random forest e SVN.

# %%
# model
lr = LinearRegression().fit(x_train, y_train)

# prediction
yhat_lr = lr.predict(x_test)

# performance
lr_result = ml_error('Linear Regression', np.expm1(y_test), np.expm1(yhat_lr)) # expm1 = exponencial para voltar o log no valor original
lr_result
# Out:
#           Model Name          MAE      MAPE         RMSE
# 0  Linear Regression  1867.089774  0.292694  2671.049215

# %% [markdown]
# ### 7.2.1. Linear Regression Model - Cross Validation

# %%
# lr_result_cv = cross_validation(x_training, 5, 'Linear Regression', lr, verbose=False)
# lr_result_cv

# # O erro real de Linear Regression é de 2952.52 + ou - 468.37

# %% [markdown]
# ## 7.3. Linear Regression Regularized Model (Modelo de Regressão Linear Regularizada) - Lasso
# Tem um parâmetro a mais, também chamado de Lasso ou Ridge e geralmente ele performa um pouco melhor que a Regressão Linear.

# %%
# model
lrr = Lasso(alpha=0.01).fit(x_train, y_train) # alpha = fator multiplicativo de cada um dos pesos para que eles fiquem dentro de um range 
                                                #e assim tenham a mesma relevância ou sejam comparáveis entre todas as variáveis
                                                #diminuindo o valor de alpha pode melhorar o valor de RMSE

# prediction
yhat_lrr = lrr.predict(x_test)

# performance
lrr_result = ml_error('Linear Regression - Lasso', np.expm1(y_test), np.expm1(yhat_lrr)) # expm1 = exponencial para voltar o log no valor original
lrr_result
# Out:
#                   Model Name          MAE      MAPE         RMSE
# 0  Linear Regression - Lasso  1891.704881  0.289106  2744.451737

# %% [markdown]
# ### 7.3.1. Lasso - Cross Validation

# %%
# lrr_result_cv = cross_validation(x_training, 5, 'Lasso', lrr, verbose=False)
# lrr_result_cv

# # O erro real de Lasso é de 3057.75 + ou - 504.26

# %% [markdown]
# ## 7.4. Random Forest Regressor
# Modelos baseado em ávores que foram adaptados para regressões.

# %%
# model
# n_estimators=100 = número de quantas árvores aleatórias ele vai criar, n_jobs=-1 = para rodar em paralelo,
# random_state=42 = origem dos números aleatórios quando ele precisar fazer a aleatoriedade
rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=42).fit(x_train, y_train)

# prediction
yhat_rf = rf.predict(x_test)

# performance
rf_result = ml_error('Random Forest Regressor', np.expm1(y_test), np.expm1(yhat_rf)) # expm1 = exponencial para voltar o log no valor original
rf_result
# Out:
#                 Model Name         MAE      MAPE         RMSE
# 0  Random Forest Regressor  679.115257  0.099842  1010.322344

# %% [markdown]
# ### 7.4.1. Random Forest Regressor - Cross Validation

# %%
# rf_result_cv = cross_validation(x_training, 5, 'Random Forest Regressor', rf, verbose=True)
# rf_result_cv

# # O erro real de Random Forest é de 1254.75 + ou - 316.61

# %% [markdown]
# ## 7.5. XGBoost Regressor
# Modelos baseado em ávores que foram adaptados para regressões. A diferença é que usa um método beggin e boost para poder selecionar as features mais rápido e mais relevantes, tem uma performance melhor.

# %%
# model

model_xgb = xgb.XGBRegressor(objective = 'reg:squarederror', # objective='reg:squarederror' = função objetiva
                             n_estimators= 100, # n_estimators = número de quantas árvores aleatórias ele vai criar
                             eta  = 0.01, # eta = quantas passadas ele usa para fazer o aprendizado
                             max_depth = 10, # max_depth = máxima ramificação (profundidade) que a árvore pode chegar
                             subsample = 0.7, # subsample = porcentagem de todas as variáveis que eu tenho que eu quero fazer uma amostragem para poder selecionar as mais relevantes
                             colsample_bytree = 0.9).fit(x_train, y_train) # colsample_bytee = fazer o sample por cada uma das árvores

# prediction
yhat_xgb = model_xgb.predict(x_test)

# performance
xgb_result = ml_error('XGBoost Regressor', np.expm1(y_test), np.expm1(yhat_xgb)) # expm1 = exponencial para voltar o log no valor original
xgb_result
# Out:
#           Model Name          MAE      MAPE         RMSE
# 0  XGBoost Regressor  6683.803417  0.949493  7331.121729

# %% [markdown]
# ### 7.5.1. XGBoost Regressor - Cross Validation

# %%
# xgb_result_cv = cross_validation(x_training, 5, 'XGBoost Regressor', model_xgb, verbose=True)
# xgb_result_cv

# # O erro real de XGBoost é de 7714.9 + ou - 689.32

# %% [markdown]
# ## 7.6. Compare Model’s Performance

# %% [markdown]
# ### 7.6.1. Single Performance

# %%
modelling_result = pd.concat([baseline_result, lr_result, lrr_result, rf_result, xgb_result])
modelling_result.sort_values('RMSE')
# Out:
#                   Model Name          MAE      MAPE         RMSE
# 0    Random Forest Regressor   679.115257  0.099842  1010.322344
# 0              Average Model  1354.800353  0.206400  1835.135542
# 0          Linear Regression  1867.089774  0.292694  2671.049215
# 0  Linear Regression - Lasso  1891.704881  0.289106  2744.451737
# 0          XGBoost Regressor  6683.803417  0.949493  7331.121729

# %% [markdown]
# ### 7.6.2. Real Performance - Cross Validation

# %% [markdown]
# A primeira iteração do Cross Validation, vamos pegar um pedaço do início até certo ponto para treinamento e vamos pegar um outro pedaço para validação, e ai vamos treinar o modelo com os dados de treinamento e validar com os dados de validação, obtendo o resultado de performance.
#
# Na segunda iteração, vamos pegar uma parte maior para fazer o treinamento que geralmente engloba o treinamento e a validação da iteração anterior e vamos chamar tudo isso de treino e aí vamos pegar um próximo pedaço que é para validação. Geralmente a validação tem o mesmo tamanho, por exemplo, como estamos fazendo a previsão para as próximas 6 semanas, os dados de validação tem sempre 6 semanas.

# %%
# modelling_result_cv = pd.concat([lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv])
# modelling_result_cv.sort_values('RMSE CV')

# %% [markdown]
# # 8.0. PASSO 08 - HYPERPARAMETER FINE TUNING

# %% [markdown]
# ## 8.1. Random Search

# %%
param = {
    'n_estimators': [1500, 1700, 2500, 3000, 3500],
    'eta': [0.01, 0.03],
    'max_depth': [3, 5, 9], # criamos listas espaçadas para tentar encontrar um conjunto que abrange todos os possíveis valores
    'subsample': [0.1, 0.5, 0.7], # é a porcentagem
    'colsample_bytree': [0.3, 0.7, 0.9],
    'min_child_weight': [3, 8, 15]
}

MAX_EVAL = 5

# %%
import random

final_result = pd.DataFrame()

for i in range(MAX_EVAL):
    # choose values for parameters randomly
    hp = { k: random.sample(v, 1)[0] for k, v in param.items() } # retorna os itens dentro do dicionário
    print(hp) # retorna a chaves valores aleatoriamente

    # model
    model_xgb = xgb.XGBRegressor(objective='reg:squarederror',
                                 n_estimators = hp['n_estimators'],
                                 eta = hp['eta'],
                                 max_depth = hp['max_depth'],
                                 subsample = hp['subsample'],
                                 colsample_bytree = hp['colsample_bytree'],
                                 min_child_weight = hp['min_child_weight'])

    # performance
    result = cross_validation(x_training, 5, 'XGBoost Regressor', model_xgb, verbose=True)
    final_result = pd.concat([final_result, result]) # concatenação do final_result com result

final_result
# Out:
# {'n_estimators': 2500, 'eta': 0.01, 'max_depth': 5, 'subsample': 0.5, 'colsample_bytree': 0.7, 'min_child_weight': 15}
#
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
# {'n_estimators': 1700, 'eta': 0.03, 'max_depth': 9, 'subsample': 0.1, 'colsample_bytree': 0.9, 'min_child_weight': 3}
#
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
# {'n_estimators': 2500, 'eta': 0.01, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 8}
#
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
# {'n_estimators': 2500, 'eta': 0.03, 'max_depth': 9, 'subsample': 0.5, 'colsample_bytree': 0.7, 'min_child_weight': 8}
#
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
# {'n_estimators': 1700, 'eta': 0.03, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 15}
#
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
#           Model Name              MAE CV        MAPE CV             RMSE CV
# 0  XGBoost Regressor  1303.53 +/- 149.29  0.18 +/- 0.01  1891.31 +/- 196.11
# 0  XGBoost Regressor   825.98 +/- 135.31  0.12 +/- 0.01  1189.29 +/- 194.84
# 0  XGBoost Regressor  1677.66 +/- 168.99  0.23 +/- 0.01  2414.99 +/- 222.53
# 0  XGBoost Regressor   792.43 +/- 132.56  0.11 +/- 0.01  1150.82 +/- 198.97
# 0  XGBoost Regressor  1491.16 +/- 159.39  0.21 +/- 0.01  2164.63 +/- 205.71

# %%
final_result
# Out:
#           Model Name              MAE CV        MAPE CV             RMSE CV
# 0  XGBoost Regressor  1303.53 +/- 149.29  0.18 +/- 0.01  1891.31 +/- 196.11
# 0  XGBoost Regressor   825.98 +/- 135.31  0.12 +/- 0.01  1189.29 +/- 194.84
# 0  XGBoost Regressor  1677.66 +/- 168.99  0.23 +/- 0.01  2414.99 +/- 222.53
# 0  XGBoost Regressor   792.43 +/- 132.56  0.11 +/- 0.01  1150.82 +/- 198.97
# 0  XGBoost Regressor  1491.16 +/- 159.39  0.21 +/- 0.01  2164.63 +/- 205.71

# %% [markdown]
# ## 8.2. Final Model

# %%
# Colocar os valores que o random forest escolheu como melhor no Random Search e deram o menor erro MAE
param_tuned = {
    'n_estimators': 2500,
    'eta': 0.03,
    'max_depth': 9,
    'subsample': 0.5,
    'colsample_bytree': 0.7,
    'min_child_weight': 8
}

# %%
# model
model_xgb_tuned = xgb.XGBRegressor(objective = 'reg:squarederror',
                                   n_estimators = param_tuned['n_estimators'],
                                   eta = param_tuned['eta'],
                                   max_depth = param_tuned['max_depth'],
                                   subsample = param_tuned['subsample'],
                                   colsample_bytree = param_tuned['colsample_bytree'],
                                   min_child_weight = param_tuned['min_child_weight']).fit(x_train, y_train)
# prediction
yhat_xgb_tuned = model_xgb_tuned.predict(x_test)

# performance
xgb_result_tuned = ml_error('XGBoost Regressor', np.expm1(y_test), np.expm1(yhat_xgb_tuned))
xgb_result_tuned
# Out:
#           Model Name         MAE     MAPE        RMSE
# 0  XGBoost Regressor  619.449999  0.09032  905.952158

# %%
# Valor mínimo do conjunto de dados
np.expm1(y_test).min()
# Out:
# 569.0000000000002

# %%
# Valor máximo do conjunto de dados
np.expm1(y_test).max()
# Out:
# 41550.99999999998

# %%
# Diferença entre o valor mínimo e máximo do conjunto de dados
np.expm1(y_test).max() - np.expm1(y_test).min()
# Out:
# 40981.99999999998

# %%
# Valor médio do conjunto de dados
np.expm1(y_test).mean()
# Out:
# 6995.162576094309

# %%
# Porcentagem de erro MAE
619/6995 * 100
# Out:
# 8.849177984274482

# %% [markdown]
# Em média, fazemos vendas de 6995 e para cada predição que esse modelo fizer temos um erro de 619 reais, que é basicamente 8% do valor médio de vendas.

# %%
# Calcular o erro MPE se o valor for positivo temos mais valores superestimados, se o valor for negativo, temos mais valores subestimados.
mpe = mean_percentage_error(np.expm1(y_test), np.expm1(yhat_xgb_tuned))
mpe
# Out:
# -0.00021887290160815332

# %% [markdown]
# # 9.0. PASSO 09 - TRADUÇÃO E INTERPRETAÇÃO DO ERRO

# %%
df9 = X_test[cols_selected_boruta_full]

# rescale = voltar para a escala original de logaritmo para exponencial
df9['sales'] = np.expm1(df9['sales'])
df9['predictions'] = np.expm1(yhat_xgb_tuned)

# %% [markdown]
# ## 9.1. Business Performance

# %%
# sum of predictions = somar as predições de cada loja
df91 = df9[['store', 'predictions']].groupby('store').sum().reset_index()

# MAE and MAPE por loja
df9_aux1 = df9[['store', 'sales', 'predictions']].groupby('store').apply(lambda x: mean_absolute_error(x['sales'], x['predictions'])).reset_index().rename(columns={0:'MAE'})
df9_aux2 = df9[['store', 'sales', 'predictions']].groupby('store').apply(lambda x: mean_absolute_percentage_error(x['sales'], x['predictions'])).reset_index().rename(columns={0:'MAPE'})

# Merge = Join
df9_aux3 = pd.merge(df9_aux1, df9_aux2, how='inner', on='store')
df92 = pd.merge(df91, df9_aux3, how='inner', on='store')

# Scenarios = subtraindo e somando o erro MAE da predição temos o pior e o melhor cenário de vendas.
df92['worst_scenario'] = df92['predictions'] - df92['MAE']
df92['best_scenario'] = df92['predictions'] + df92['MAE']

# order columns
df92 = df92[['store', 'predictions', 'worst_scenario', 'best_scenario', 'MAE', 'MAPE']]

# %%
df92.head()
# Out:
#    store    predictions  worst_scenario  best_scenario         MAE      MAPE
# 0      1  161311.671875   161035.585304  161587.758446  276.086571  0.062902
# 1      2  175678.515625   175340.039392  176016.991858  338.476233  0.071572
# 2      3  261889.421875   261308.524810  262470.318940  580.897065  0.081818
# 3      4  343729.531250   342869.654983  344589.407517  859.876267  0.081634
# 4      5  173037.625000   172657.329293  173417.920707  380.295707  0.085004

# %% [markdown]
# - A **loja 1** nas próximas 6 semanas vai vender 161 mil e pode ter um erro de 276 e esse erro de 276 corresponde a 6% das vendas reais em média que essa loja faz.
#
#
# - A **loja 2** nas próximas 6 semanas vai vender 175 mil e pode ter um erro de 338 e esse erro de 338 corresponde a 7% das vendas reais em média que essa loja faz.
#
#
# - A **loja 3** nas próximas 6 semanas vai vender 261 mil e pode ter um erro de 580 e esse erro de 580 corresponde a 8% das vendas reais em média que essa loja faz.
#
#
# - A **loja 4** nas próximas 6 semanas vai vender 343 mil e pode ter um erro de 859 e esse erro de 859 corresponde a 8% das vendas reais em média que essa loja faz.
#
#
# - A **loja 5** nas próximas 6 semanas vai vender 173 mil e pode ter um erro de 380 e esse erro de 380 corresponde a 8% das vendas reais em média que essa loja faz.

# %%
# Mostrar as lojas que são mais difíceis para fazer a predição
df92.sort_values('MAPE', ascending=False).head()
# Out:
#      store    predictions  worst_scenario  best_scenario          MAE      MAPE
# 291    292  105373.601562   102058.780775  108688.422350  3314.820788  0.554939
# 908    909  237286.390625   229772.631751  244800.149499  7513.758874  0.507183
# 875    876  205734.125000   201752.086543  209716.163457  3982.038457  0.306027
# 594    595  385468.687500   381583.706213  389353.668787  3884.981287  0.265859
# 721    722  351576.281250   349622.760175  353529.802325  1953.521075  0.260858

# %%
# Mostrar as lojas que são mais difíceis para fazer a predição com scatterplot
sns.scatterplot(x='store', y='MAPE', data=df92)
# Out:
# <AxesSubplot:xlabel='store', ylabel='MAPE'>

# %% [markdown]
# ## 9.2. Total Performance

# %% [markdown]
# A soma de predições para as próximas 6 semanas em todas as lojas é de 286 milhões, onde no pior cenário vamos fazer 285 milhões e no melhor cenário vamos fazer 286 milhões.

# %%
df93 = df92[['predictions', 'worst_scenario', 'best_scenario']].apply(lambda x: np.sum(x), axis=0).reset_index().rename(columns={'index': 'Scenario', 0:'Values'})
df93['Values'] = df93['Values'].map('R${:,.2f}'.format)
df93
# Out:
#          Scenario            Values
# 0     predictions  R$285,053,632.00
# 1  worst_scenario  R$284,358,720.77
# 2   best_scenario  R$285,748,526.49

# %% [markdown]
# ## 9.3. Machine Learning Performance

# %%
df9['error'] = df9['sales'] - df9['predictions']
df9['error_rate'] = df9['predictions'] / df9['sales']

# %%
plt.subplot(2, 2, 1)
sns.lineplot(x='date', y='sales', data=df9, label='SALES')
sns.lineplot(x='date', y='predictions', data=df9, label='PREDICTIONS')

# Porcentagem de predições em relação as vendas. Taxa de erro por dia. Se for igual a 1 = previsão perfeita. 
# Se for acima do 1 = superestimação (predições maiores que as vendas). Se for abaixo do 1 = subestimação (predições menores que as vendas).
plt.subplot(2, 2, 2)
sns.lineplot(x='date', y='error_rate', data=df9)
plt.axhline(1, linestyle='--')

# Gráfico de distribuição, para saber se o erro tem uma distribuição parecida com a normal. Análise do resíduo.
plt.subplot(2, 2, 3)
sns.distplot(df9['error'])

# Scatterplot, predições em relação ao erro. O gráfico mostra que sempre que fazemos predições entre 8000 e 10000 temos erros maiores.
plt.subplot(2, 2, 4 )
sns.scatterplot(df9['predictions'], df9['error'])
# Out:
# <AxesSubplot:xlabel='predictions', ylabel='error'>

# %% [markdown]
# # 10.0. PASSO 10 - DEPLOY MODEL PRODUCTION

# %%
# Guarda valores serializados entre 0 e 1, método para salvar modelos treinados
pickle.dump(model_xgb_tuned, open('/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/model/model_rossmann.pkl', 'wb'))

# %% [markdown]
# ## 10.1. Rossmann Class

# %%
import pickle
import inflection
import pandas as pd
import numpy as np
import math
import datetime

class Rossmann( object ):
    def __init__( self ):
        self.home_path = '/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/model/'
        self.competition_distance_scaler = pickle.load( open( self.home_path + 'parameter/competition_distance_scaler.pkl', 'rb') )
        self.competition_time_month_scaler = pickle.load( open( self.home_path + 'parameter/competition_time_month_scaler.pkl', 'rb') )
        self.promo_time_week_scaler = pickle.load( open( self.home_path + 'parameter/promo_time_week_scaler.pkl', 'rb') )
        self.year_scaler = pickle.load( open( self.home_path + 'parameter/year_scaler.pkl', 'rb') )
        self.store_type_scaler = pickle.load( open( self.home_path + 'parameter/store_type_scaler.pkl', 'rb') )

    def data_cleaning( self, df1 ):
    
        ## 1.1. Rename Columns
        cols_old = ['Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday','StoreType', 'Assortment'
                    ,'CompetitionDistance','CompetitionOpenSinceMonth','CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
                    'Promo2SinceYear', 'PromoInterval']
        
        snakecase = lambda x: inflection.underscore( x )
        cols_new = list( map( snakecase, cols_old ) )

        # rename
        df1.columns = cols_new

        # 1.3. Data Types
        df1['date'] = pd.to_datetime( df1['date'] )

        ## 1.5. Fillout NA
        #competition_distance
        df1['competition_distance'] = df1['competition_distance'].apply( lambda x: 200000.0 if math.isnan( x ) else x )

        #competition_open_since_month
        df1['competition_open_since_month'] = df1.apply( lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] ) 
                                                        else x['competition_open_since_month'], axis=1 )

        #competition_open_since_year
        df1['competition_open_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] ) 
                                                       else x['competition_open_since_year'], axis=1 )

        #promo2_since_week
        df1['promo2_since_week'] = df1.apply( lambda x: x['date'].week if math.isnan( x['promo2_since_week'] ) else x['promo2_since_week'], axis=1 )

        #promo2_since_year
        df1['promo2_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['promo2_since_year'] ) else x['promo2_since_year'], axis=1 )

        #promo_interval
        month_map = {1: 'Jan', 2: 'Fev', 3: 'Mar', 4: 'Apr', 5: 'May', 6:'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
        df1['promo_interval'].fillna(0, inplace=True )
        df1['month_map'] = df1['date'].dt.month.map( month_map )
        df1['is_promo'] = df1[['promo_interval', 'month_map']].apply( lambda x:0 if x['promo_interval'] == 0 
                                                                     else 1 if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 )

        ## 1.6. Change Data Types
        # competiton
        df1['competition_open_since_month'] = df1['competition_open_since_month'].astype( int )
        df1['competition_open_since_year'] = df1['competition_open_since_year'].astype( int )

        # promo2
        df1['promo2_since_week'] = df1['promo2_since_week'].astype( int )
        df1['promo2_since_year'] = df1['promo2_since_year'].astype( int )
        
        return df1

    def feature_engineering( self, df2 ):
        # year
        df2['year'] = df2['date'].dt.year

        # month
        df2['month'] = df2['date'].dt.month

        # day
        df2['day'] = df2['date'].dt.day

        # week of year
        df2['week_of_year'] = df2['date'].dt.weekofyear

        # year week
        df2['year_week'] = df2['date'].dt.strftime( '%Y-%W' )

        # competition since
        df2['competition_since'] = df2.apply( lambda x: datetime.datetime(year=x['competition_open_since_year'], month=x['competition_open_since_month'],day=1 ), axis=1 )
        df2['competition_time_month'] = ( ( df2['date'] - df2['competition_since'] )/30 ).apply( lambda x: x.days ).astype( int )

        # promo since
        df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )
        df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta( days=7 ) )
        df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply( lambda x: x.days ).astype( int )

        # assortment
        df2['assortment'] = df2['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )
        # state holiday
        df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' 
                                                          else 'christmas' if x == 'c' else 'regular_day' )

        # 3.0. PASSO 03 - FILTRAGEM DE VARIÁVEIS
        ## 3.1. Filtragem das Linhas
        df2 = df2[df2['open'] != 0]

        ## 3.2. Selecao das Colunas
        cols_drop = ['open', 'promo_interval', 'month_map']
        df2 = df2.drop( cols_drop, axis=1 )
        
        return df2

    def data_preparation( self, df5 ):
        
        ## 5.2. Rescaling
        # competition distance
        df5['competition_distance'] = self.competition_distance_scaler.fit_transform( df5[['competition_distance']].values )

        # competition time month
        df5['competition_time_month'] = self.competition_time_month_scaler.fit_transform( df5[['competition_time_month']].values )

        # promo time week
        df5['promo_time_week'] = self.promo_time_week_scaler.fit_transform(df5[['promo_time_week']].values )

        # year
        df5['year'] = self.year_scaler.fit_transform( df5[['year']].values )

        ### 5.3.1. Encoding
        # state_holiday - One Hot Encoding
        df5 = pd.get_dummies( df5, prefix=['state_holiday'], columns=['state_holiday'] )

        # store_type - Label Encoding
        df5['store_type'] = self.store_type_scaler.fit_transform(df5['store_type'] )

        # assortment - Ordinal Encoding
        assortment_dict = {'basic': 1, 'extra': 2, 'extended': 3}
        df5['assortment'] = df5['assortment'].map( assortment_dict )

        ### 5.3.3. Nature Transformation
        # day of week
        df5['day_of_week_sin'] = df5['day_of_week'].apply( lambda x: np.sin( x * ( 2. * np.pi/7 ) ) )
        df5['day_of_week_cos'] = df5['day_of_week'].apply( lambda x: np.cos( x * ( 2. * np.pi/7 ) ) )

        # month
        df5['month_sin'] = df5['month'].apply( lambda x: np.sin( x * ( 2. * np.pi/12 ) ) )
        df5['month_cos'] = df5['month'].apply( lambda x: np.cos( x * ( 2. * np.pi/12 ) ) )

        # day

        df5['day_sin'] = df5['day'].apply( lambda x: np.sin( x * ( 2. * np.pi/30 ) ) )

        df5['day_cos'] = df5['day'].apply( lambda x: np.cos( x * ( 2. * np.pi/30 ) ) )

        # week of year
        df5['week_of_year_sin'] = df5['week_of_year'].apply( lambda x: np.sin(x * ( 2. * np.pi/52 ) ) )
        df5['week_of_year_cos'] = df5['week_of_year'].apply( lambda x: np.cos(x * ( 2. * np.pi/52 ) ) )

        cols_selected = [ 'store', 'promo', 'store_type', 'assortment','competition_distance', 'competition_open_since_month',
                         'competition_open_since_year', 'promo2', 'promo2_since_week','promo2_since_year', 'competition_time_month',
                         'promo_time_week','day_of_week_sin', 'day_of_week_cos', 'month_sin', 'month_cos','day_sin', 'day_cos',
                         'week_of_year_sin', 'week_of_year_cos']
        
        return df5[ cols_selected ]

    def get_prediction( self, model, original_data, test_data ):
    
        # prediction
        pred = model.predict( test_data )

        # join pred into the original data
        original_data['prediction'] = np.expm1( pred ) # criar coluna prediction e fazer a re-escala de logaritmo para exponencial
        
        return original_data.to_json( orient='records', date_format='iso' )

# %% [markdown]
# ## 10.2. API Handler

# %%
import pickle
import pandas as pd
from flask import Flask, request, Response
from rossmann.Rossmann import Rossmann

# loading model
model = pickle.load(open('/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/model/model_rossmann.pkl', 'rb'))

# initialize API
app = Flask(__name__)

@app.route('/rossmann/predict', methods=['POST'])         
def rossmann_predict():
    test_json = request.get_json()
    
    if test_json: # there is data
        if isinstance(test_json, dict): # unique example
            test_raw = pd.DataFrame(test_json, index=[0])
    
        else: # multiple example
            test_raw = pd.DataFrame(test_json, columns=test_json[0].keys())
    
        # Instantiate Rossmann class
        pipeline = Rossmann()
        
        # data cleaning
        df1 = pipeline.data_cleaning(test_raw)
        
        # feature engineering
        df2 = pipeline.feature_engineering(df1)
        
        # data preparation
        df3 = pipeline.data_preparation(df2)
        
        # prediction
        df_response = pipeline.get_prediction(model, test_raw, df3)
        return df_response

    else:
        return Reponse('{}', status=200, mimetype='application/json')
    
if __name__ == '__main__':
    app.run('192.168.68.108') # indica localhost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-101-54f279274101> in <module>
#       2 import pandas as pd
#       3 from flask import Flask, request, Response
# ----> 4 from rossmann.Rossmann import Rossmann
#       5
#       6 # loading model
#
# ModuleNotFoundError: No module named 'rossmann'

# %% [markdown]
# ## 10.3. API Tester

# %%
# loading test dataset
df10 = pd.read_csv( '/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/datasets/test.csv' )

# %%
# merge test dataset + store
df_test = pd.merge(df10, df_store_raw, how='left', on='Store')

# choose store for prediction
#df_test = df_test[df_test['Store'].isin([20, 23, 22])]

# remove closed days (loja fechada)
df_test = df_test[df_test['Open'] != 0]
df_test = df_test[~df_test['Open'].isnull()]
df_test = df_test.drop('Id', axis=1)

# %%
# convert Dataframe to json
data = json.dumps(df_test.to_dict(orient='records'))

# %%
# Rodar primeiro o handler.py no terminal, alterar endereço ipv4. Depois rodar aqui
# API Call
url = 'http://192.168.68.108:5000/rossmann/predict'
#url = 'https://rossmann-model-test.herokuapp.com/rossmann/predict'
header = {'Content-type': 'application/json'}
data = data

r = requests.post(url, data=data, headers=header)
print('Status Code {}'.format(r.status_code))
# Out:
# Status Code 200

# %%
# Criar variável d1, usar o constrututor do pandas pd.DataFrame, acessar o json e montar as colunas pegando somente a primera 
# linha (columns=r.json()[0]), acessar os keys para pegar todas as colunas para montar o nome da coluna
d1 = pd.DataFrame(r.json(), columns=r.json()[0].keys())

# %%
d1.head()
# Out:
#    store  day_of_week                      date  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year   promo_interval month_map  is_promo  year  month  day  week_of_year year_week         competition_since  competition_time_month               promo_since  promo_time_week   prediction
# 0      1            4  2015-09-17T00:00:00.000Z   1.0      1   regular_day               0          c      basic                1270.0                             9                         2008       0                 38               2015                0       Sep         0  2015      9   17            38   2015-37  2008-09-01T00:00:00.000Z                      85  2015-09-14T00:00:00.000Z                0  4748.232422
# 1      3            4  2015-09-17T00:00:00.000Z   1.0      1   regular_day               0          a      basic               14130.0                            12                         2006       1                 14               2011  Jan,Apr,Jul,Oct       Sep         0  2015      9   17            38   2015-37  2006-12-01T00:00:00.000Z                     107  2011-03-28T00:00:00.000Z              233  7560.105957
# 2      7            4  2015-09-17T00:00:00.000Z   1.0      1   regular_day               0          a   extended               24000.0                             4                         2013       0                 38               2015                0       Sep         0  2015      9   17            38   2015-37  2013-04-01T00:00:00.000Z                      29  2015-09-14T00:00:00.000Z                0  8617.632812
# 3      8            4  2015-09-17T00:00:00.000Z   1.0      1   regular_day               0          a      basic                7520.0                            10                         2014       0                 38               2015                0       Sep         0  2015      9   17            38   2015-37  2014-10-01T00:00:00.000Z                      11  2015-09-14T00:00:00.000Z                0  6837.868652
# 4      9            4  2015-09-17T00:00:00.000Z   1.0      1   regular_day               0          a   extended                2030.0                             8                         2000       0                 38               2015                0       Sep         0  2015      9   17            38   2015-37  2000-08-01T00:00:00.000Z                     184  2015-09-14T00:00:00.000Z                0  6948.195801

# %%
# Mostra o valor da soma das lojas escolhidas no bloco "10.3. API Tester choose store for prediction",
# quanto vai vender no final de 6 semanas

d2 = d1[['store', 'prediction']].groupby('store').sum().reset_index()

for i in range(len(d2)):
    print('A loja número {} venderá R$ {:,.2f} nas próximas 6 semanas'.format
          (d2.loc[i, 'store'], d2.loc[i, 'prediction']))
# Out:
# A loja número 1 venderá R$ 190,692.09 nas próximas 6 semanas
# A loja número 3 venderá R$ 276,715.15 nas próximas 6 semanas
# A loja número 7 venderá R$ 322,376.66 nas próximas 6 semanas
# A loja número 8 venderá R$ 252,269.31 nas próximas 6 semanas
# A loja número 9 venderá R$ 277,934.14 nas próximas 6 semanas
# A loja número 10 venderá R$ 196,379.61 nas próximas 6 semanas
# A loja número 11 venderá R$ 319,643.01 nas próximas 6 semanas
# A loja número 12 venderá R$ 240,693.92 nas próximas 6 semanas
# A loja número 13 venderá R$ 223,405.42 nas próximas 6 semanas
# A loja número 14 venderá R$ 218,188.69 nas próximas 6 semanas
# A loja número 15 venderá R$ 280,473.26 nas próximas 6 semanas
# A loja número 16 venderá R$ 286,767.94 nas próximas 6 semanas
# A loja número 19 venderá R$ 235,954.58 nas próximas 6 semanas
# A loja número 20 venderá R$ 272,277.22 nas próximas 6 semanas
# A loja número 21 venderá R$ 205,489.35 nas próximas 6 semanas
# A loja número 22 venderá R$ 193,555.14 nas próximas 6 semanas
# A loja número 23 venderá R$ 222,126.12 nas próximas 6 semanas
# A loja número 24 venderá R$ 358,842.35 nas próximas 6 semanas
# A loja número 25 venderá R$ 425,067.53 nas próximas 6 semanas
# A loja número 27 venderá R$ 273,141.88 nas próximas 6 semanas
# A loja número 29 venderá R$ 275,457.69 nas próximas 6 semanas
# A loja número 30 venderá R$ 176,249.32 nas próximas 6 semanas
# A loja número 31 venderá R$ 221,775.24 nas próximas 6 semanas
# A loja número 32 venderá R$ 166,098.68 nas próximas 6 semanas
# A loja número 33 venderá R$ 290,102.13 nas próximas 6 semanas
# A loja número 35 venderá R$ 360,783.15 nas próximas 6 semanas
# A loja número 36 venderá R$ 410,061.62 nas próximas 6 semanas
# A loja número 38 venderá R$ 206,015.87 nas próximas 6 semanas
# A loja número 39 venderá R$ 156,191.18 nas próximas 6 semanas
# A loja número 40 venderá R$ 198,109.71 nas próximas 6 semanas
# A loja número 41 venderá R$ 193,057.67 nas próximas 6 semanas
# A loja número 42 venderá R$ 342,012.23 nas próximas 6 semanas
# A loja número 43 venderá R$ 250,666.18 nas próximas 6 semanas
# A loja número 45 venderá R$ 205,261.79 nas próximas 6 semanas
# A loja número 46 venderá R$ 198,696.88 nas próximas 6 semanas
# A loja número 47 venderá R$ 194,049.50 nas próximas 6 semanas
# A loja número 48 venderá R$ 216,158.55 nas próximas 6 semanas
# A loja número 49 venderá R$ 215,955.80 nas próximas 6 semanas
# A loja número 50 venderá R$ 161,544.52 nas próximas 6 semanas
# A loja número 51 venderá R$ 271,775.80 nas próximas 6 semanas
# A loja número 52 venderá R$ 332,042.01 nas próximas 6 semanas
# A loja número 53 venderá R$ 173,151.48 nas próximas 6 semanas
# A loja número 56 venderá R$ 260,851.57 nas próximas 6 semanas
# A loja número 58 venderá R$ 225,934.01 nas próximas 6 semanas
# A loja número 61 venderá R$ 258,456.65 nas próximas 6 semanas
# A loja número 62 venderá R$ 275,574.03 nas próximas 6 semanas
# A loja número 63 venderá R$ 257,503.34 nas próximas 6 semanas
# A loja número 64 venderá R$ 286,921.31 nas próximas 6 semanas
# A loja número 66 venderá R$ 225,906.09 nas próximas 6 semanas
# A loja número 67 venderá R$ 391,089.20 nas próximas 6 semanas
# A loja número 68 venderá R$ 246,577.02 nas próximas 6 semanas
# A loja número 69 venderá R$ 257,531.14 nas próximas 6 semanas
# A loja número 70 venderá R$ 272,184.37 nas próximas 6 semanas
# A loja número 71 venderá R$ 351,079.13 nas próximas 6 semanas
# A loja número 72 venderá R$ 196,800.69 nas próximas 6 semanas
# A loja número 73 venderá R$ 207,546.05 nas próximas 6 semanas
# A loja número 74 venderá R$ 227,149.40 nas próximas 6 semanas
# A loja número 75 venderá R$ 321,765.96 nas próximas 6 semanas
# A loja número 76 venderá R$ 393,500.74 nas próximas 6 semanas
# A loja número 77 venderá R$ 237,964.23 nas próximas 6 semanas
# A loja número 79 venderá R$ 209,455.48 nas próximas 6 semanas
# A loja número 80 venderá R$ 242,604.63 nas próximas 6 semanas
# A loja número 81 venderá R$ 265,445.03 nas próximas 6 semanas
# A loja número 82 venderá R$ 419,332.94 nas próximas 6 semanas
# A loja número 83 venderá R$ 207,527.70 nas próximas 6 semanas
# A loja número 84 venderá R$ 373,687.50 nas próximas 6 semanas
# A loja número 86 venderá R$ 247,936.35 nas próximas 6 semanas
# A loja número 89 venderá R$ 239,468.94 nas próximas 6 semanas
# A loja número 90 venderá R$ 275,092.39 nas próximas 6 semanas
# A loja número 91 venderá R$ 224,077.82 nas próximas 6 semanas
# A loja número 92 venderá R$ 249,861.67 nas próximas 6 semanas
# A loja número 93 venderá R$ 228,825.37 nas próximas 6 semanas
# A loja número 94 venderá R$ 310,186.78 nas próximas 6 semanas
# A loja número 98 venderá R$ 243,319.15 nas próximas 6 semanas
# A loja número 99 venderá R$ 222,243.55 nas próximas 6 semanas
# A loja número 100 venderá R$ 195,133.68 nas próximas 6 semanas
# A loja número 101 venderá R$ 251,771.47 nas próximas 6 semanas
# A loja número 102 venderá R$ 205,601.45 nas próximas 6 semanas
# A loja número 105 venderá R$ 122,515.60 nas próximas 6 semanas
# A loja número 107 venderá R$ 260,236.49 nas próximas 6 semanas
# A loja número 108 venderá R$ 358,035.74 nas próximas 6 semanas
# A loja número 109 venderá R$ 237,484.28 nas próximas 6 semanas
# A loja número 110 venderá R$ 176,314.80 nas próximas 6 semanas
# A loja número 111 venderá R$ 254,950.79 nas próximas 6 semanas
# A loja número 112 venderá R$ 267,827.52 nas próximas 6 semanas
# A loja número 113 venderá R$ 238,813.98 nas próximas 6 semanas
# A loja número 115 venderá R$ 256,350.96 nas próximas 6 semanas
# A loja número 117 venderá R$ 186,289.71 nas próximas 6 semanas
# A loja número 118 venderá R$ 292,924.41 nas próximas 6 semanas
# A loja número 119 venderá R$ 241,574.49 nas próximas 6 semanas
# A loja número 120 venderá R$ 276,170.79 nas próximas 6 semanas
# A loja número 122 venderá R$ 259,398.55 nas próximas 6 semanas
# A loja número 124 venderá R$ 243,727.58 nas próximas 6 semanas
# A loja número 126 venderá R$ 237,335.70 nas próximas 6 semanas
# A loja número 127 venderá R$ 267,351.96 nas próximas 6 semanas
# A loja número 128 venderá R$ 236,038.34 nas próximas 6 semanas
# A loja número 129 venderá R$ 249,556.08 nas próximas 6 semanas
# A loja número 130 venderá R$ 235,390.26 nas próximas 6 semanas
# A loja número 131 venderá R$ 285,687.72 nas próximas 6 semanas
# A loja número 132 venderá R$ 219,127.94 nas próximas 6 semanas
# A loja número 135 venderá R$ 221,985.57 nas próximas 6 semanas
# A loja número 136 venderá R$ 247,146.52 nas próximas 6 semanas
# A loja número 137 venderá R$ 273,204.42 nas próximas 6 semanas
# A loja número 139 venderá R$ 214,171.65 nas próximas 6 semanas
# A loja número 140 venderá R$ 225,370.87 nas próximas 6 semanas
# A loja número 141 venderá R$ 267,094.02 nas próximas 6 semanas
# A loja número 142 venderá R$ 169,879.90 nas próximas 6 semanas
# A loja número 143 venderá R$ 253,309.09 nas próximas 6 semanas
# A loja número 144 venderá R$ 238,752.71 nas próximas 6 semanas
# A loja número 145 venderá R$ 294,760.63 nas próximas 6 semanas
# A loja número 146 venderá R$ 264,102.64 nas próximas 6 semanas
# A loja número 147 venderá R$ 300,362.58 nas próximas 6 semanas
# A loja número 149 venderá R$ 222,956.01 nas próximas 6 semanas
# A loja número 150 venderá R$ 222,518.16 nas próximas 6 semanas
# A loja número 152 venderá R$ 256,737.01 nas próximas 6 semanas
# A loja número 153 venderá R$ 249,956.63 nas próximas 6 semanas
# A loja número 154 venderá R$ 270,001.83 nas próximas 6 semanas
# A loja número 155 venderá R$ 252,799.42 nas próximas 6 semanas
# A loja número 157 venderá R$ 330,316.99 nas próximas 6 semanas
# A loja número 158 venderá R$ 339,703.75 nas próximas 6 semanas
# A loja número 159 venderá R$ 301,657.64 nas próximas 6 semanas
# A loja número 160 venderá R$ 241,985.26 nas próximas 6 semanas
# A loja número 161 venderá R$ 262,623.74 nas próximas 6 semanas
# A loja número 162 venderá R$ 301,983.98 nas próximas 6 semanas
# A loja número 164 venderá R$ 179,468.44 nas próximas 6 semanas
# A loja número 165 venderá R$ 175,787.35 nas próximas 6 semanas
# A loja número 166 venderá R$ 225,047.51 nas próximas 6 semanas
# A loja número 168 venderá R$ 298,153.52 nas próximas 6 semanas
# A loja número 169 venderá R$ 294,697.90 nas próximas 6 semanas
# A loja número 170 venderá R$ 195,514.71 nas próximas 6 semanas
# A loja número 171 venderá R$ 317,029.92 nas próximas 6 semanas
# A loja número 172 venderá R$ 268,753.57 nas próximas 6 semanas
# A loja número 174 venderá R$ 176,309.28 nas próximas 6 semanas
# A loja número 175 venderá R$ 260,915.52 nas próximas 6 semanas
# A loja número 176 venderá R$ 225,109.04 nas próximas 6 semanas
# A loja número 179 venderá R$ 422,940.84 nas próximas 6 semanas
# A loja número 180 venderá R$ 251,619.91 nas próximas 6 semanas
# A loja número 181 venderá R$ 245,104.57 nas próximas 6 semanas
# A loja número 182 venderá R$ 322,793.79 nas próximas 6 semanas
# A loja número 183 venderá R$ 233,623.59 nas próximas 6 semanas
# A loja número 184 venderá R$ 253,893.61 nas próximas 6 semanas
# A loja número 186 venderá R$ 160,476.24 nas próximas 6 semanas
# A loja número 187 venderá R$ 255,438.13 nas próximas 6 semanas
# A loja número 188 venderá R$ 205,780.82 nas próximas 6 semanas
# A loja número 189 venderá R$ 287,636.38 nas próximas 6 semanas
# A loja número 190 venderá R$ 235,939.07 nas próximas 6 semanas
# A loja número 191 venderá R$ 200,293.11 nas próximas 6 semanas
# A loja número 192 venderá R$ 253,507.26 nas próximas 6 semanas
# A loja número 193 venderá R$ 224,410.12 nas próximas 6 semanas
# A loja número 194 venderá R$ 182,934.66 nas próximas 6 semanas
# A loja número 195 venderá R$ 244,107.96 nas próximas 6 semanas
# A loja número 197 venderá R$ 235,019.89 nas próximas 6 semanas
# A loja número 199 venderá R$ 282,388.59 nas próximas 6 semanas
# A loja número 200 venderá R$ 294,079.00 nas próximas 6 semanas
# A loja número 201 venderá R$ 229,345.83 nas próximas 6 semanas
# A loja número 202 venderá R$ 221,497.43 nas próximas 6 semanas
# A loja número 204 venderá R$ 204,833.46 nas próximas 6 semanas
# A loja número 206 venderá R$ 263,908.90 nas próximas 6 semanas
# A loja número 207 venderá R$ 322,754.53 nas próximas 6 semanas
# A loja número 209 venderá R$ 204,362.13 nas próximas 6 semanas
# A loja número 210 venderá R$ 144,561.98 nas próximas 6 semanas
# A loja número 212 venderá R$ 229,972.62 nas próximas 6 semanas
# A loja número 213 venderá R$ 240,792.73 nas próximas 6 semanas
# A loja número 214 venderá R$ 292,840.36 nas próximas 6 semanas
# A loja número 215 venderá R$ 266,719.57 nas próximas 6 semanas
# A loja número 216 venderá R$ 282,343.95 nas próximas 6 semanas
# A loja número 217 venderá R$ 217,843.51 nas próximas 6 semanas
# A loja número 218 venderá R$ 279,980.92 nas próximas 6 semanas
# A loja número 219 venderá R$ 130,786.09 nas próximas 6 semanas
# A loja número 220 venderá R$ 227,726.33 nas próximas 6 semanas
# A loja número 221 venderá R$ 233,564.18 nas próximas 6 semanas
# A loja número 224 venderá R$ 198,224.89 nas próximas 6 semanas
# A loja número 226 venderá R$ 319,037.62 nas próximas 6 semanas
# A loja número 227 venderá R$ 281,700.53 nas próximas 6 semanas
# A loja número 228 venderá R$ 330,079.27 nas próximas 6 semanas
# A loja número 229 venderá R$ 346,114.32 nas próximas 6 semanas
# A loja número 230 venderá R$ 271,163.47 nas próximas 6 semanas
# A loja número 231 venderá R$ 220,292.70 nas próximas 6 semanas
# A loja número 233 venderá R$ 337,241.54 nas próximas 6 semanas
# A loja número 234 venderá R$ 342,243.48 nas próximas 6 semanas
# A loja número 235 venderá R$ 233,450.69 nas próximas 6 semanas
# A loja número 238 venderá R$ 309,633.12 nas próximas 6 semanas
# A loja número 239 venderá R$ 169,260.97 nas próximas 6 semanas
# A loja número 241 venderá R$ 237,595.83 nas próximas 6 semanas
# A loja número 242 venderá R$ 171,494.14 nas próximas 6 semanas
# A loja número 243 venderá R$ 287,785.84 nas próximas 6 semanas
# A loja número 244 venderá R$ 200,415.66 nas próximas 6 semanas
# A loja número 245 venderá R$ 302,725.31 nas próximas 6 semanas
# A loja número 246 venderá R$ 260,750.51 nas próximas 6 semanas
# A loja número 247 venderá R$ 202,216.14 nas próximas 6 semanas
# A loja número 248 venderá R$ 415,589.77 nas próximas 6 semanas
# A loja número 249 venderá R$ 175,382.71 nas próximas 6 semanas
# A loja número 250 venderá R$ 250,164.48 nas próximas 6 semanas
# A loja número 251 venderá R$ 453,901.92 nas próximas 6 semanas
# A loja número 252 venderá R$ 440,074.77 nas próximas 6 semanas
# A loja número 253 venderá R$ 228,634.88 nas próximas 6 semanas
# A loja número 254 venderá R$ 194,484.82 nas próximas 6 semanas
# A loja número 255 venderá R$ 266,492.76 nas próximas 6 semanas
# A loja número 256 venderá R$ 218,161.50 nas próximas 6 semanas
# A loja número 258 venderá R$ 229,486.55 nas próximas 6 semanas
# A loja número 259 venderá R$ 346,710.82 nas próximas 6 semanas
# A loja número 262 venderá R$ 547,645.09 nas próximas 6 semanas
# A loja número 263 venderá R$ 142,754.46 nas próximas 6 semanas
# A loja número 265 venderá R$ 197,764.84 nas próximas 6 semanas
# A loja número 267 venderá R$ 263,246.98 nas próximas 6 semanas
# A loja número 268 venderá R$ 185,127.63 nas próximas 6 semanas
# A loja número 269 venderá R$ 267,150.59 nas próximas 6 semanas
# A loja número 272 venderá R$ 216,230.06 nas próximas 6 semanas
# A loja número 273 venderá R$ 254,973.98 nas próximas 6 semanas
# A loja número 274 venderá R$ 196,366.25 nas próximas 6 semanas
# A loja número 275 venderá R$ 228,901.79 nas próximas 6 semanas
# A loja número 277 venderá R$ 246,105.72 nas próximas 6 semanas
# A loja número 278 venderá R$ 229,087.21 nas próximas 6 semanas
# A loja número 279 venderá R$ 283,667.25 nas próximas 6 semanas
# A loja número 280 venderá R$ 224,856.98 nas próximas 6 semanas
# A loja número 281 venderá R$ 224,556.74 nas próximas 6 semanas
# A loja número 283 venderá R$ 247,507.66 nas próximas 6 semanas
# A loja número 284 venderá R$ 222,600.08 nas próximas 6 semanas
# A loja número 285 venderá R$ 255,757.56 nas próximas 6 semanas
# A loja número 287 venderá R$ 300,911.11 nas próximas 6 semanas
# A loja número 288 venderá R$ 199,603.32 nas próximas 6 semanas
# A loja número 289 venderá R$ 241,840.51 nas próximas 6 semanas
# A loja número 290 venderá R$ 240,690.74 nas próximas 6 semanas
# A loja número 294 venderá R$ 240,868.08 nas próximas 6 semanas
# A loja número 295 venderá R$ 175,218.60 nas próximas 6 semanas
# A loja número 296 venderá R$ 243,973.67 nas próximas 6 semanas
# A loja número 297 venderá R$ 247,625.18 nas próximas 6 semanas
# A loja número 298 venderá R$ 358,808.16 nas próximas 6 semanas
# A loja número 299 venderá R$ 282,341.56 nas próximas 6 semanas
# A loja número 300 venderá R$ 224,762.43 nas próximas 6 semanas
# A loja número 301 venderá R$ 230,526.82 nas próximas 6 semanas
# A loja número 302 venderá R$ 172,955.23 nas próximas 6 semanas
# A loja número 303 venderá R$ 279,241.79 nas próximas 6 semanas
# A loja número 304 venderá R$ 283,422.01 nas próximas 6 semanas
# A loja número 305 venderá R$ 171,554.57 nas próximas 6 semanas
# A loja número 306 venderá R$ 167,024.34 nas próximas 6 semanas
# A loja número 308 venderá R$ 307,363.35 nas próximas 6 semanas
# A loja número 309 venderá R$ 296,277.35 nas próximas 6 semanas
# A loja número 310 venderá R$ 331,333.40 nas próximas 6 semanas
# A loja número 311 venderá R$ 281,211.59 nas próximas 6 semanas
# A loja número 312 venderá R$ 223,078.71 nas próximas 6 semanas
# A loja número 314 venderá R$ 161,183.57 nas próximas 6 semanas
# A loja número 315 venderá R$ 187,417.99 nas próximas 6 semanas
# A loja número 316 venderá R$ 329,008.98 nas próximas 6 semanas
# A loja número 317 venderá R$ 242,131.55 nas próximas 6 semanas
# A loja número 319 venderá R$ 359,515.47 nas próximas 6 semanas
# A loja número 320 venderá R$ 246,413.08 nas próximas 6 semanas
# A loja número 323 venderá R$ 256,699.90 nas próximas 6 semanas
# A loja número 325 venderá R$ 355,310.32 nas próximas 6 semanas
# A loja número 326 venderá R$ 183,257.35 nas próximas 6 semanas
# A loja número 328 venderá R$ 207,249.23 nas próximas 6 semanas
# A loja número 329 venderá R$ 246,187.92 nas próximas 6 semanas
# A loja número 330 venderá R$ 191,952.73 nas próximas 6 semanas
# A loja número 331 venderá R$ 270,072.85 nas próximas 6 semanas
# A loja número 333 venderá R$ 328,946.17 nas próximas 6 semanas
# A loja número 334 venderá R$ 193,553.03 nas próximas 6 semanas
# A loja número 335 venderá R$ 454,105.07 nas próximas 6 semanas
# A loja número 336 venderá R$ 324,869.43 nas próximas 6 semanas
# A loja número 337 venderá R$ 196,932.38 nas próximas 6 semanas
# A loja número 338 venderá R$ 298,198.36 nas próximas 6 semanas
# A loja número 339 venderá R$ 191,565.12 nas próximas 6 semanas
# A loja número 340 venderá R$ 267,509.25 nas próximas 6 semanas
# A loja número 341 venderá R$ 178,453.05 nas próximas 6 semanas
# A loja número 342 venderá R$ 401,083.78 nas próximas 6 semanas
# A loja número 343 venderá R$ 257,390.00 nas próximas 6 semanas
# A loja número 344 venderá R$ 296,831.95 nas próximas 6 semanas
# A loja número 345 venderá R$ 200,615.71 nas próximas 6 semanas
# A loja número 346 venderá R$ 265,773.90 nas próximas 6 semanas
# A loja número 347 venderá R$ 218,608.60 nas próximas 6 semanas
# A loja número 348 venderá R$ 231,402.93 nas próximas 6 semanas
# A loja número 350 venderá R$ 241,470.05 nas próximas 6 semanas
# A loja número 351 venderá R$ 231,099.55 nas próximas 6 semanas
# A loja número 352 venderá R$ 232,478.21 nas próximas 6 semanas
# A loja número 353 venderá R$ 272,111.17 nas próximas 6 semanas
# A loja número 354 venderá R$ 338,906.68 nas próximas 6 semanas
# A loja número 355 venderá R$ 311,254.53 nas próximas 6 semanas
# A loja número 356 venderá R$ 229,802.59 nas próximas 6 semanas
# A loja número 358 venderá R$ 360,840.84 nas próximas 6 semanas
# A loja número 359 venderá R$ 287,404.00 nas próximas 6 semanas
# A loja número 362 venderá R$ 360,095.00 nas próximas 6 semanas
# A loja número 364 venderá R$ 204,192.66 nas próximas 6 semanas
# A loja número 365 venderá R$ 215,741.57 nas próximas 6 semanas
# A loja número 367 venderá R$ 219,453.49 nas próximas 6 semanas
# A loja número 368 venderá R$ 340,688.56 nas próximas 6 semanas
# A loja número 369 venderá R$ 288,557.44 nas próximas 6 semanas
# A loja número 370 venderá R$ 301,174.15 nas próximas 6 semanas
# A loja número 371 venderá R$ 262,443.74 nas próximas 6 semanas
# A loja número 372 venderá R$ 300,910.71 nas próximas 6 semanas
# A loja número 373 venderá R$ 211,508.78 nas próximas 6 semanas
# A loja número 377 venderá R$ 288,539.04 nas próximas 6 semanas
# A loja número 378 venderá R$ 264,245.28 nas próximas 6 semanas
# A loja número 379 venderá R$ 196,382.24 nas próximas 6 semanas
# A loja número 380 venderá R$ 411,521.19 nas próximas 6 semanas
# A loja número 383 venderá R$ 509,766.89 nas próximas 6 semanas
# A loja número 385 venderá R$ 292,138.98 nas próximas 6 semanas
# A loja número 386 venderá R$ 270,971.24 nas próximas 6 semanas
# A loja número 387 venderá R$ 320,910.41 nas próximas 6 semanas
# A loja número 388 venderá R$ 399,256.40 nas próximas 6 semanas
# A loja número 389 venderá R$ 401,061.88 nas próximas 6 semanas
# A loja número 391 venderá R$ 310,034.29 nas próximas 6 semanas
# A loja número 392 venderá R$ 295,735.36 nas próximas 6 semanas
# A loja número 393 venderá R$ 259,261.47 nas próximas 6 semanas
# A loja número 394 venderá R$ 228,841.67 nas próximas 6 semanas
# A loja número 395 venderá R$ 211,133.40 nas próximas 6 semanas
# A loja número 397 venderá R$ 247,180.48 nas próximas 6 semanas
# A loja número 398 venderá R$ 243,540.80 nas próximas 6 semanas
# A loja número 399 venderá R$ 226,795.53 nas próximas 6 semanas
# A loja número 403 venderá R$ 315,182.76 nas próximas 6 semanas
# A loja número 404 venderá R$ 197,038.03 nas próximas 6 semanas
# A loja número 405 venderá R$ 182,122.75 nas próximas 6 semanas
# A loja número 406 venderá R$ 218,624.68 nas próximas 6 semanas
# A loja número 407 venderá R$ 162,201.74 nas próximas 6 semanas
# A loja número 408 venderá R$ 232,523.47 nas próximas 6 semanas
# A loja número 409 venderá R$ 172,358.79 nas próximas 6 semanas
# A loja número 410 venderá R$ 190,125.98 nas próximas 6 semanas
# A loja número 411 venderá R$ 345,882.72 nas próximas 6 semanas
# A loja número 412 venderá R$ 336,167.16 nas próximas 6 semanas
# A loja número 413 venderá R$ 302,700.97 nas próximas 6 semanas
# A loja número 414 venderá R$ 233,721.27 nas próximas 6 semanas
# A loja número 415 venderá R$ 262,219.15 nas próximas 6 semanas
# A loja número 416 venderá R$ 388,708.53 nas próximas 6 semanas
# A loja número 417 venderá R$ 265,437.94 nas próximas 6 semanas
# A loja número 418 venderá R$ 256,885.56 nas próximas 6 semanas
# A loja número 420 venderá R$ 200,688.63 nas próximas 6 semanas
# A loja número 421 venderá R$ 242,015.98 nas próximas 6 semanas
# A loja número 422 venderá R$ 282,900.57 nas próximas 6 semanas
# A loja número 424 venderá R$ 277,474.94 nas próximas 6 semanas
# A loja número 425 venderá R$ 289,623.28 nas próximas 6 semanas
# A loja número 426 venderá R$ 258,474.51 nas próximas 6 semanas
# A loja número 427 venderá R$ 232,694.02 nas próximas 6 semanas
# A loja número 428 venderá R$ 230,458.22 nas próximas 6 semanas
# A loja número 429 venderá R$ 192,343.35 nas próximas 6 semanas
# A loja número 430 venderá R$ 263,644.53 nas próximas 6 semanas
# A loja número 431 venderá R$ 391,851.60 nas próximas 6 semanas
# A loja número 432 venderá R$ 361,494.25 nas próximas 6 semanas
# A loja número 433 venderá R$ 215,229.32 nas próximas 6 semanas
# A loja número 434 venderá R$ 222,507.77 nas próximas 6 semanas
# A loja número 435 venderá R$ 248,959.03 nas próximas 6 semanas
# A loja número 440 venderá R$ 225,640.52 nas próximas 6 semanas
# A loja número 441 venderá R$ 277,718.58 nas próximas 6 semanas
# A loja número 442 venderá R$ 253,533.96 nas próximas 6 semanas
# A loja número 445 venderá R$ 308,698.56 nas próximas 6 semanas
# A loja número 446 venderá R$ 263,683.51 nas próximas 6 semanas
# A loja número 447 venderá R$ 277,145.47 nas próximas 6 semanas
# A loja número 448 venderá R$ 308,069.56 nas próximas 6 semanas
# A loja número 449 venderá R$ 448,220.19 nas próximas 6 semanas
# A loja número 450 venderá R$ 311,099.62 nas próximas 6 semanas
# A loja número 451 venderá R$ 187,854.96 nas próximas 6 semanas
# A loja número 452 venderá R$ 217,650.02 nas próximas 6 semanas
# A loja número 453 venderá R$ 367,016.17 nas próximas 6 semanas
# A loja número 455 venderá R$ 263,770.11 nas próximas 6 semanas
# A loja número 456 venderá R$ 283,049.06 nas próximas 6 semanas
# A loja número 457 venderá R$ 143,234.14 nas próximas 6 semanas
# A loja número 458 venderá R$ 284,945.22 nas próximas 6 semanas
# A loja número 459 venderá R$ 221,190.82 nas próximas 6 semanas
# A loja número 461 venderá R$ 191,716.69 nas próximas 6 semanas
# A loja número 463 venderá R$ 310,252.78 nas próximas 6 semanas
# A loja número 465 venderá R$ 197,783.66 nas próximas 6 semanas
# A loja número 466 venderá R$ 340,305.85 nas próximas 6 semanas
# A loja número 467 venderá R$ 496,709.71 nas próximas 6 semanas
# A loja número 468 venderá R$ 258,098.08 nas próximas 6 semanas
# A loja número 470 venderá R$ 354,567.89 nas próximas 6 semanas
# A loja número 471 venderá R$ 265,253.85 nas próximas 6 semanas
# A loja número 472 venderá R$ 210,008.28 nas próximas 6 semanas
# A loja número 473 venderá R$ 185,359.66 nas próximas 6 semanas
# A loja número 475 venderá R$ 188,321.98 nas próximas 6 semanas
# A loja número 477 venderá R$ 194,021.17 nas próximas 6 semanas
# A loja número 481 venderá R$ 193,951.74 nas próximas 6 semanas
# A loja número 484 venderá R$ 232,184.33 nas próximas 6 semanas
# A loja número 485 venderá R$ 199,907.31 nas próximas 6 semanas
# A loja número 486 venderá R$ 208,048.80 nas próximas 6 semanas
# A loja número 487 venderá R$ 224,354.44 nas próximas 6 semanas
# A loja número 488 venderá R$ 238,989.56 nas próximas 6 semanas
# A loja número 490 venderá R$ 231,854.06 nas próximas 6 semanas
# A loja número 491 venderá R$ 254,696.61 nas próximas 6 semanas
# A loja número 492 venderá R$ 247,858.61 nas próximas 6 semanas
# A loja número 493 venderá R$ 230,354.22 nas próximas 6 semanas
# A loja número 495 venderá R$ 224,265.11 nas próximas 6 semanas
# A loja número 497 venderá R$ 340,227.73 nas próximas 6 semanas
# A loja número 498 venderá R$ 322,756.26 nas próximas 6 semanas
# A loja número 499 venderá R$ 292,856.72 nas próximas 6 semanas
# A loja número 500 venderá R$ 188,161.28 nas próximas 6 semanas
# A loja número 501 venderá R$ 269,834.05 nas próximas 6 semanas
# A loja número 502 venderá R$ 323,842.69 nas próximas 6 semanas
# A loja número 504 venderá R$ 383,114.14 nas próximas 6 semanas
# A loja número 505 venderá R$ 241,646.97 nas próximas 6 semanas
# A loja número 506 venderá R$ 308,121.39 nas próximas 6 semanas
# A loja número 507 venderá R$ 331,063.27 nas próximas 6 semanas
# A loja número 508 venderá R$ 306,571.19 nas próximas 6 semanas
# A loja número 509 venderá R$ 248,773.99 nas próximas 6 semanas
# A loja número 510 venderá R$ 303,148.61 nas próximas 6 semanas
# A loja número 511 venderá R$ 273,513.86 nas próximas 6 semanas
# A loja número 512 venderá R$ 331,079.98 nas próximas 6 semanas
# A loja número 514 venderá R$ 234,987.81 nas próximas 6 semanas
# A loja número 515 venderá R$ 353,176.41 nas próximas 6 semanas
# A loja número 516 venderá R$ 304,184.64 nas próximas 6 semanas
# A loja número 517 venderá R$ 316,699.62 nas próximas 6 semanas
# A loja número 518 venderá R$ 233,277.70 nas próximas 6 semanas
# A loja número 519 venderá R$ 199,060.11 nas próximas 6 semanas
# A loja número 520 venderá R$ 164,353.24 nas próximas 6 semanas
# A loja número 521 venderá R$ 193,825.48 nas próximas 6 semanas
# A loja número 522 venderá R$ 346,400.36 nas próximas 6 semanas
# A loja número 524 venderá R$ 299,758.89 nas próximas 6 semanas
# A loja número 527 venderá R$ 387,209.55 nas próximas 6 semanas
# A loja número 528 venderá R$ 418,973.07 nas próximas 6 semanas
# A loja número 529 venderá R$ 268,803.40 nas próximas 6 semanas
# A loja número 530 venderá R$ 195,528.10 nas próximas 6 semanas
# A loja número 531 venderá R$ 260,790.73 nas próximas 6 semanas
# A loja número 532 venderá R$ 392,806.02 nas próximas 6 semanas
# A loja número 533 venderá R$ 406,604.85 nas próximas 6 semanas
# A loja número 534 venderá R$ 263,447.81 nas próximas 6 semanas
# A loja número 535 venderá R$ 276,906.08 nas próximas 6 semanas
# A loja número 536 venderá R$ 309,845.91 nas próximas 6 semanas
# A loja número 537 venderá R$ 232,519.00 nas próximas 6 semanas
# A loja número 538 venderá R$ 216,749.34 nas próximas 6 semanas
# A loja número 539 venderá R$ 323,495.09 nas próximas 6 semanas
# A loja número 540 venderá R$ 248,597.06 nas próximas 6 semanas
# A loja número 541 venderá R$ 401,746.73 nas próximas 6 semanas
# A loja número 542 venderá R$ 210,048.15 nas próximas 6 semanas
# A loja número 543 venderá R$ 128,657.41 nas próximas 6 semanas
# A loja número 545 venderá R$ 302,794.16 nas próximas 6 semanas
# A loja número 547 venderá R$ 236,855.31 nas próximas 6 semanas
# A loja número 548 venderá R$ 227,806.39 nas próximas 6 semanas
# A loja número 549 venderá R$ 272,026.99 nas próximas 6 semanas
# A loja número 550 venderá R$ 266,181.96 nas próximas 6 semanas
# A loja número 551 venderá R$ 223,677.42 nas próximas 6 semanas
# A loja número 552 venderá R$ 294,911.43 nas próximas 6 semanas
# A loja número 553 venderá R$ 257,907.78 nas próximas 6 semanas
# A loja número 554 venderá R$ 239,848.75 nas próximas 6 semanas
# A loja número 555 venderá R$ 170,849.42 nas próximas 6 semanas
# A loja número 557 venderá R$ 214,729.33 nas próximas 6 semanas
# A loja número 558 venderá R$ 150,917.54 nas próximas 6 semanas
# A loja número 561 venderá R$ 268,729.66 nas próximas 6 semanas
# A loja número 562 venderá R$ 631,200.87 nas próximas 6 semanas
# A loja número 563 venderá R$ 226,799.02 nas próximas 6 semanas
# A loja número 564 venderá R$ 184,862.97 nas próximas 6 semanas
# A loja número 565 venderá R$ 216,018.96 nas próximas 6 semanas
# A loja número 566 venderá R$ 224,264.41 nas próximas 6 semanas
# A loja número 567 venderá R$ 232,470.09 nas próximas 6 semanas
# A loja número 568 venderá R$ 212,805.33 nas próximas 6 semanas
# A loja número 570 venderá R$ 164,492.25 nas próximas 6 semanas
# A loja número 571 venderá R$ 247,977.25 nas próximas 6 semanas
# A loja número 572 venderá R$ 289,176.29 nas próximas 6 semanas
# A loja número 573 venderá R$ 162,725.74 nas próximas 6 semanas
# A loja número 574 venderá R$ 363,535.81 nas próximas 6 semanas
# A loja número 575 venderá R$ 242,887.86 nas próximas 6 semanas
# A loja número 577 venderá R$ 220,952.04 nas próximas 6 semanas
# A loja número 578 venderá R$ 309,851.42 nas próximas 6 semanas
# A loja número 579 venderá R$ 317,787.48 nas próximas 6 semanas
# A loja número 580 venderá R$ 301,410.93 nas próximas 6 semanas
# A loja número 581 venderá R$ 206,193.88 nas próximas 6 semanas
# A loja número 582 venderá R$ 286,298.18 nas próximas 6 semanas
# A loja número 584 venderá R$ 288,694.28 nas próximas 6 semanas
# A loja número 585 venderá R$ 267,250.99 nas próximas 6 semanas
# A loja número 586 venderá R$ 280,688.13 nas próximas 6 semanas
# A loja número 587 venderá R$ 404,884.14 nas próximas 6 semanas
# A loja número 588 venderá R$ 277,740.68 nas próximas 6 semanas
# A loja número 589 venderá R$ 254,182.82 nas próximas 6 semanas
# A loja número 590 venderá R$ 189,418.46 nas próximas 6 semanas
# A loja número 591 venderá R$ 209,296.82 nas próximas 6 semanas
# A loja número 592 venderá R$ 186,980.94 nas próximas 6 semanas
# A loja número 593 venderá R$ 232,669.78 nas próximas 6 semanas
# A loja número 597 venderá R$ 172,966.62 nas próximas 6 semanas
# A loja número 598 venderá R$ 193,150.10 nas próximas 6 semanas
# A loja número 600 venderá R$ 302,079.17 nas próximas 6 semanas
# A loja número 601 venderá R$ 227,201.38 nas próximas 6 semanas
# A loja número 602 venderá R$ 225,825.79 nas próximas 6 semanas
# A loja número 603 venderá R$ 356,548.33 nas próximas 6 semanas
# A loja número 604 venderá R$ 195,543.39 nas próximas 6 semanas
# A loja número 605 venderá R$ 285,140.05 nas próximas 6 semanas
# A loja número 610 venderá R$ 213,706.64 nas próximas 6 semanas
# A loja número 611 venderá R$ 214,110.60 nas próximas 6 semanas
# A loja número 612 venderá R$ 256,351.48 nas próximas 6 semanas
# A loja número 615 venderá R$ 294,284.80 nas próximas 6 semanas
# A loja número 616 venderá R$ 306,368.02 nas próximas 6 semanas
# A loja número 618 venderá R$ 276,992.93 nas próximas 6 semanas
# A loja número 619 venderá R$ 192,750.99 nas próximas 6 semanas
# A loja número 620 venderá R$ 281,243.06 nas próximas 6 semanas
# A loja número 621 venderá R$ 217,727.22 nas próximas 6 semanas
# A loja número 622 venderá R$ 123,504.23 nas próximas 6 semanas
# A loja número 623 venderá R$ 278,742.46 nas próximas 6 semanas
# A loja número 624 venderá R$ 260,048.71 nas próximas 6 semanas
# A loja número 625 venderá R$ 224,778.45 nas próximas 6 semanas
# A loja número 627 venderá R$ 249,518.71 nas próximas 6 semanas
# A loja número 628 venderá R$ 279,694.67 nas próximas 6 semanas
# A loja número 629 venderá R$ 255,411.96 nas próximas 6 semanas
# A loja número 631 venderá R$ 263,548.79 nas próximas 6 semanas
# A loja número 632 venderá R$ 226,641.62 nas próximas 6 semanas
# A loja número 633 venderá R$ 237,522.87 nas próximas 6 semanas
# A loja número 636 venderá R$ 235,210.62 nas próximas 6 semanas
# A loja número 637 venderá R$ 340,935.09 nas próximas 6 semanas
# A loja número 638 venderá R$ 224,056.32 nas próximas 6 semanas
# A loja número 639 venderá R$ 254,939.91 nas próximas 6 semanas
# A loja número 640 venderá R$ 350,004.22 nas próximas 6 semanas
# A loja número 641 venderá R$ 160,389.09 nas próximas 6 semanas
# A loja número 642 venderá R$ 227,586.80 nas próximas 6 semanas
# A loja número 643 venderá R$ 273,238.63 nas próximas 6 semanas
# A loja número 644 venderá R$ 355,483.10 nas próximas 6 semanas
# A loja número 645 venderá R$ 345,038.85 nas próximas 6 semanas
# A loja número 646 venderá R$ 173,729.44 nas próximas 6 semanas
# A loja número 647 venderá R$ 257,833.78 nas próximas 6 semanas
# A loja número 650 venderá R$ 195,540.06 nas próximas 6 semanas
# A loja número 651 venderá R$ 295,228.90 nas próximas 6 semanas
# A loja número 653 venderá R$ 277,602.81 nas próximas 6 semanas
# A loja número 655 venderá R$ 258,801.73 nas próximas 6 semanas
# A loja número 656 venderá R$ 215,344.55 nas próximas 6 semanas
# A loja número 657 venderá R$ 181,516.40 nas próximas 6 semanas
# A loja número 658 venderá R$ 319,941.36 nas próximas 6 semanas
# A loja número 659 venderá R$ 234,685.59 nas próximas 6 semanas
# A loja número 660 venderá R$ 186,696.45 nas próximas 6 semanas
# A loja número 661 venderá R$ 261,691.62 nas próximas 6 semanas
# A loja número 662 venderá R$ 308,054.99 nas próximas 6 semanas
# A loja número 663 venderá R$ 184,783.64 nas próximas 6 semanas
# A loja número 665 venderá R$ 243,718.60 nas próximas 6 semanas
# A loja número 666 venderá R$ 256,693.44 nas próximas 6 semanas
# A loja número 667 venderá R$ 353,941.62 nas próximas 6 semanas
# A loja número 669 venderá R$ 181,349.16 nas próximas 6 semanas
# A loja número 670 venderá R$ 264,220.29 nas próximas 6 semanas
# A loja número 671 venderá R$ 289,813.08 nas próximas 6 semanas
# A loja número 673 venderá R$ 251,993.85 nas próximas 6 semanas
# A loja número 674 venderá R$ 271,261.80 nas próximas 6 semanas
# A loja número 675 venderá R$ 174,699.18 nas próximas 6 semanas
# A loja número 676 venderá R$ 479,474.19 nas próximas 6 semanas
# A loja número 677 venderá R$ 248,852.24 nas próximas 6 semanas
# A loja número 678 venderá R$ 262,010.38 nas próximas 6 semanas
# A loja número 680 venderá R$ 225,453.43 nas próximas 6 semanas
# A loja número 681 venderá R$ 124,546.02 nas próximas 6 semanas
# A loja número 684 venderá R$ 261,169.26 nas próximas 6 semanas
# A loja número 685 venderá R$ 325,459.55 nas próximas 6 semanas
# A loja número 687 venderá R$ 339,354.20 nas próximas 6 semanas
# A loja número 689 venderá R$ 276,963.44 nas próximas 6 semanas
# A loja número 690 venderá R$ 273,667.64 nas próximas 6 semanas
# A loja número 691 venderá R$ 284,318.02 nas próximas 6 semanas
# A loja número 692 venderá R$ 201,685.11 nas próximas 6 semanas
# A loja número 693 venderá R$ 315,539.46 nas próximas 6 semanas
# A loja número 694 venderá R$ 399,298.17 nas próximas 6 semanas
# A loja número 695 venderá R$ 184,436.88 nas próximas 6 semanas
# A loja número 696 venderá R$ 351,533.00 nas próximas 6 semanas
# A loja número 697 venderá R$ 305,113.29 nas próximas 6 semanas
# A loja número 699 venderá R$ 312,905.85 nas próximas 6 semanas
# A loja número 700 venderá R$ 138,118.99 nas próximas 6 semanas
# A loja número 701 venderá R$ 228,818.19 nas próximas 6 semanas
# A loja número 702 venderá R$ 182,223.62 nas próximas 6 semanas
# A loja número 703 venderá R$ 131,359.04 nas próximas 6 semanas
# A loja número 705 venderá R$ 299,663.83 nas próximas 6 semanas
# A loja número 706 venderá R$ 241,181.13 nas próximas 6 semanas
# A loja número 707 venderá R$ 345,173.13 nas próximas 6 semanas
# A loja número 710 venderá R$ 210,192.05 nas próximas 6 semanas
# A loja número 711 venderá R$ 294,443.62 nas próximas 6 semanas
# A loja número 712 venderá R$ 251,067.54 nas próximas 6 semanas
# A loja número 713 venderá R$ 309,551.53 nas próximas 6 semanas
# A loja número 714 venderá R$ 173,293.22 nas próximas 6 semanas
# A loja número 716 venderá R$ 220,892.86 nas próximas 6 semanas
# A loja número 717 venderá R$ 421,398.54 nas próximas 6 semanas
# A loja número 718 venderá R$ 244,922.32 nas próximas 6 semanas
# A loja número 719 venderá R$ 228,313.15 nas próximas 6 semanas
# A loja número 720 venderá R$ 249,277.99 nas próximas 6 semanas
# A loja número 721 venderá R$ 354,244.71 nas próximas 6 semanas
# A loja número 722 venderá R$ 313,036.12 nas próximas 6 semanas
# A loja número 723 venderá R$ 234,219.74 nas próximas 6 semanas
# A loja número 724 venderá R$ 286,344.47 nas próximas 6 semanas
# A loja número 725 venderá R$ 260,663.71 nas próximas 6 semanas
# A loja número 727 venderá R$ 241,136.27 nas próximas 6 semanas
# A loja número 728 venderá R$ 219,458.33 nas próximas 6 semanas
# A loja número 729 venderá R$ 321,477.65 nas próximas 6 semanas
# A loja número 731 venderá R$ 347,009.37 nas próximas 6 semanas
# A loja número 732 venderá R$ 249,660.80 nas próximas 6 semanas
# A loja número 733 venderá R$ 443,059.50 nas próximas 6 semanas
# A loja número 734 venderá R$ 272,548.24 nas próximas 6 semanas
# A loja número 736 venderá R$ 261,063.54 nas próximas 6 semanas
# A loja número 737 venderá R$ 243,440.82 nas próximas 6 semanas
# A loja número 738 venderá R$ 290,270.78 nas próximas 6 semanas
# A loja número 739 venderá R$ 342,428.44 nas próximas 6 semanas
# A loja número 740 venderá R$ 280,316.42 nas próximas 6 semanas
# A loja número 741 venderá R$ 283,489.74 nas próximas 6 semanas
# A loja número 742 venderá R$ 325,771.06 nas próximas 6 semanas
# A loja número 744 venderá R$ 243,623.51 nas próximas 6 semanas
# A loja número 746 venderá R$ 254,428.47 nas próximas 6 semanas
# A loja número 748 venderá R$ 240,655.16 nas próximas 6 semanas
# A loja número 749 venderá R$ 214,853.31 nas próximas 6 semanas
# A loja número 750 venderá R$ 218,401.77 nas próximas 6 semanas
# A loja número 751 venderá R$ 272,052.56 nas próximas 6 semanas
# A loja número 752 venderá R$ 206,369.17 nas próximas 6 semanas
# A loja número 753 venderá R$ 382,895.04 nas próximas 6 semanas
# A loja número 756 venderá R$ 385,989.07 nas próximas 6 semanas
# A loja número 757 venderá R$ 319,758.61 nas próximas 6 semanas
# A loja número 758 venderá R$ 267,576.45 nas próximas 6 semanas
# A loja número 759 venderá R$ 229,041.43 nas próximas 6 semanas
# A loja número 762 venderá R$ 191,382.84 nas próximas 6 semanas
# A loja número 763 venderá R$ 192,003.73 nas próximas 6 semanas
# A loja número 764 venderá R$ 129,162.54 nas próximas 6 semanas
# A loja número 765 venderá R$ 316,075.96 nas próximas 6 semanas
# A loja número 766 venderá R$ 227,135.86 nas próximas 6 semanas
# A loja número 767 venderá R$ 212,295.18 nas próximas 6 semanas
# A loja número 768 venderá R$ 388,777.30 nas próximas 6 semanas
# A loja número 769 venderá R$ 335,885.84 nas próximas 6 semanas
# A loja número 770 venderá R$ 304,925.78 nas próximas 6 semanas
# A loja número 771 venderá R$ 287,131.61 nas próximas 6 semanas
# A loja número 772 venderá R$ 235,695.92 nas próximas 6 semanas
# A loja número 773 venderá R$ 258,254.60 nas próximas 6 semanas
# A loja número 774 venderá R$ 286,116.67 nas próximas 6 semanas
# A loja número 775 venderá R$ 331,107.46 nas próximas 6 semanas
# A loja número 776 venderá R$ 222,603.11 nas próximas 6 semanas
# A loja número 777 venderá R$ 164,394.34 nas próximas 6 semanas
# A loja número 778 venderá R$ 280,060.61 nas próximas 6 semanas
# A loja número 782 venderá R$ 220,789.34 nas próximas 6 semanas
# A loja número 784 venderá R$ 203,804.62 nas próximas 6 semanas
# A loja número 785 venderá R$ 204,829.25 nas próximas 6 semanas
# A loja número 789 venderá R$ 149,520.01 nas próximas 6 semanas
# A loja número 790 venderá R$ 239,423.42 nas próximas 6 semanas
# A loja número 791 venderá R$ 283,300.88 nas próximas 6 semanas
# A loja número 792 venderá R$ 276,211.97 nas próximas 6 semanas
# A loja número 793 venderá R$ 186,705.04 nas próximas 6 semanas
# A loja número 795 venderá R$ 191,591.94 nas próximas 6 semanas
# A loja número 796 venderá R$ 269,590.38 nas próximas 6 semanas
# A loja número 797 venderá R$ 159,359.43 nas próximas 6 semanas
# A loja número 799 venderá R$ 307,652.92 nas próximas 6 semanas
# A loja número 800 venderá R$ 229,081.47 nas próximas 6 semanas
# A loja número 801 venderá R$ 183,840.51 nas próximas 6 semanas
# A loja número 802 venderá R$ 258,775.34 nas próximas 6 semanas
# A loja número 803 venderá R$ 248,099.52 nas próximas 6 semanas
# A loja número 804 venderá R$ 188,880.35 nas próximas 6 semanas
# A loja número 805 venderá R$ 197,153.09 nas próximas 6 semanas
# A loja número 806 venderá R$ 301,521.93 nas próximas 6 semanas
# A loja número 807 venderá R$ 335,541.52 nas próximas 6 semanas
# A loja número 809 venderá R$ 319,630.74 nas próximas 6 semanas
# A loja número 810 venderá R$ 250,589.54 nas próximas 6 semanas
# A loja número 811 venderá R$ 273,840.94 nas próximas 6 semanas
# A loja número 813 venderá R$ 245,986.71 nas próximas 6 semanas
# A loja número 815 venderá R$ 372,465.65 nas próximas 6 semanas
# A loja número 816 venderá R$ 354,942.64 nas próximas 6 semanas
# A loja número 818 venderá R$ 232,596.57 nas próximas 6 semanas
# A loja número 819 venderá R$ 290,268.47 nas próximas 6 semanas
# A loja número 820 venderá R$ 341,305.20 nas próximas 6 semanas
# A loja número 822 venderá R$ 491,679.44 nas próximas 6 semanas
# A loja número 823 venderá R$ 248,146.13 nas próximas 6 semanas
# A loja número 824 venderá R$ 231,858.21 nas próximas 6 semanas
# A loja número 825 venderá R$ 246,253.61 nas próximas 6 semanas
# A loja número 826 venderá R$ 275,618.17 nas próximas 6 semanas
# A loja número 829 venderá R$ 244,930.82 nas próximas 6 semanas
# A loja número 831 venderá R$ 330,188.67 nas próximas 6 semanas
# A loja número 832 venderá R$ 224,122.23 nas próximas 6 semanas
# A loja número 833 venderá R$ 223,896.37 nas próximas 6 semanas
# A loja número 835 venderá R$ 222,005.81 nas próximas 6 semanas
# A loja número 837 venderá R$ 257,324.66 nas próximas 6 semanas
# A loja número 840 venderá R$ 252,064.36 nas próximas 6 semanas
# A loja número 842 venderá R$ 529,668.83 nas próximas 6 semanas
# A loja número 844 venderá R$ 200,515.27 nas próximas 6 semanas
# A loja número 845 venderá R$ 200,517.23 nas próximas 6 semanas
# A loja número 846 venderá R$ 360,931.04 nas próximas 6 semanas
# A loja número 847 venderá R$ 263,544.92 nas próximas 6 semanas
# A loja número 848 venderá R$ 335,785.66 nas próximas 6 semanas
# A loja número 849 venderá R$ 288,252.54 nas próximas 6 semanas
# A loja número 850 venderá R$ 189,576.30 nas próximas 6 semanas
# A loja número 851 venderá R$ 208,963.95 nas próximas 6 semanas
# A loja número 852 venderá R$ 225,848.87 nas próximas 6 semanas
# A loja número 853 venderá R$ 271,863.58 nas próximas 6 semanas
# A loja número 855 venderá R$ 240,744.09 nas próximas 6 semanas
# A loja número 856 venderá R$ 241,673.55 nas próximas 6 semanas
# A loja número 857 venderá R$ 256,058.78 nas próximas 6 semanas
# A loja número 858 venderá R$ 168,786.35 nas próximas 6 semanas
# A loja número 859 venderá R$ 367,792.31 nas próximas 6 semanas
# A loja número 860 venderá R$ 223,091.34 nas próximas 6 semanas
# A loja número 861 venderá R$ 166,872.46 nas próximas 6 semanas
# A loja número 862 venderá R$ 350,243.16 nas próximas 6 semanas
# A loja número 863 venderá R$ 258,081.98 nas próximas 6 semanas
# A loja número 864 venderá R$ 224,230.09 nas próximas 6 semanas
# A loja número 865 venderá R$ 307,835.74 nas próximas 6 semanas
# A loja número 866 venderá R$ 246,931.63 nas próximas 6 semanas
# A loja número 867 venderá R$ 327,533.40 nas próximas 6 semanas
# A loja número 868 venderá R$ 317,971.90 nas próximas 6 semanas
# A loja número 871 venderá R$ 328,416.29 nas próximas 6 semanas
# A loja número 872 venderá R$ 277,204.36 nas próximas 6 semanas
# A loja número 874 venderá R$ 241,981.36 nas próximas 6 semanas
# A loja número 875 venderá R$ 191,453.63 nas próximas 6 semanas
# A loja número 877 venderá R$ 236,475.41 nas próximas 6 semanas
# A loja número 879 venderá R$ 137,243.91 nas próximas 6 semanas
# A loja número 880 venderá R$ 352,098.20 nas próximas 6 semanas
# A loja número 881 venderá R$ 219,202.50 nas próximas 6 semanas
# A loja número 882 venderá R$ 229,972.24 nas próximas 6 semanas
# A loja número 883 venderá R$ 184,255.91 nas próximas 6 semanas
# A loja número 884 venderá R$ 272,779.66 nas próximas 6 semanas
# A loja número 885 venderá R$ 240,756.65 nas próximas 6 semanas
# A loja número 886 venderá R$ 273,017.95 nas próximas 6 semanas
# A loja número 887 venderá R$ 305,802.32 nas próximas 6 semanas
# A loja número 888 venderá R$ 297,487.81 nas próximas 6 semanas
# A loja número 890 venderá R$ 249,677.34 nas próximas 6 semanas
# A loja número 891 venderá R$ 308,850.64 nas próximas 6 semanas
# A loja número 893 venderá R$ 255,243.73 nas próximas 6 semanas
# A loja número 894 venderá R$ 203,073.08 nas próximas 6 semanas
# A loja número 895 venderá R$ 372,176.16 nas próximas 6 semanas
# A loja número 896 venderá R$ 209,535.66 nas próximas 6 semanas
# A loja número 897 venderá R$ 133,359.34 nas próximas 6 semanas
# A loja número 900 venderá R$ 227,997.07 nas próximas 6 semanas
# A loja número 901 venderá R$ 252,629.29 nas próximas 6 semanas
# A loja número 902 venderá R$ 301,496.13 nas próximas 6 semanas
# A loja número 903 venderá R$ 290,631.21 nas próximas 6 semanas
# A loja número 904 venderá R$ 334,861.52 nas próximas 6 semanas
# A loja número 905 venderá R$ 246,054.75 nas próximas 6 semanas
# A loja número 906 venderá R$ 275,967.23 nas próximas 6 semanas
# A loja número 907 venderá R$ 281,575.58 nas próximas 6 semanas
# A loja número 908 venderá R$ 187,324.42 nas próximas 6 semanas
# A loja número 909 venderá R$ 310,149.16 nas próximas 6 semanas
# A loja número 911 venderá R$ 311,211.75 nas próximas 6 semanas
# A loja número 912 venderá R$ 280,350.67 nas próximas 6 semanas
# A loja número 913 venderá R$ 286,186.13 nas próximas 6 semanas
# A loja número 914 venderá R$ 309,958.60 nas próximas 6 semanas
# A loja número 915 venderá R$ 260,208.85 nas próximas 6 semanas
# A loja número 916 venderá R$ 181,038.07 nas próximas 6 semanas
# A loja número 917 venderá R$ 236,988.58 nas próximas 6 semanas
# A loja número 919 venderá R$ 205,806.72 nas próximas 6 semanas
# A loja número 920 venderá R$ 196,430.50 nas próximas 6 semanas
# A loja número 922 venderá R$ 258,270.14 nas próximas 6 semanas
# A loja número 924 venderá R$ 197,891.50 nas próximas 6 semanas
# A loja número 925 venderá R$ 327,639.44 nas próximas 6 semanas
# A loja número 926 venderá R$ 289,586.69 nas próximas 6 semanas
# A loja número 927 venderá R$ 324,413.84 nas próximas 6 semanas
# A loja número 928 venderá R$ 245,197.10 nas próximas 6 semanas
# A loja número 929 venderá R$ 251,617.12 nas próximas 6 semanas
# A loja número 930 venderá R$ 271,628.83 nas próximas 6 semanas
# A loja número 931 venderá R$ 193,527.12 nas próximas 6 semanas
# A loja número 932 venderá R$ 307,060.32 nas próximas 6 semanas
# A loja número 934 venderá R$ 244,566.52 nas próximas 6 semanas
# A loja número 935 venderá R$ 329,483.74 nas próximas 6 semanas
# A loja número 936 venderá R$ 279,708.41 nas próximas 6 semanas
# A loja número 937 venderá R$ 297,523.59 nas próximas 6 semanas
# A loja número 938 venderá R$ 252,824.85 nas próximas 6 semanas
# A loja número 939 venderá R$ 315,242.72 nas próximas 6 semanas
# A loja número 941 venderá R$ 186,194.85 nas próximas 6 semanas
# A loja número 942 venderá R$ 260,128.01 nas próximas 6 semanas
# A loja número 943 venderá R$ 229,121.80 nas próximas 6 semanas
# A loja número 944 venderá R$ 276,871.92 nas próximas 6 semanas
# A loja número 945 venderá R$ 225,960.26 nas próximas 6 semanas
# A loja número 946 venderá R$ 160,055.94 nas próximas 6 semanas
# A loja número 947 venderá R$ 333,460.72 nas próximas 6 semanas
# A loja número 948 venderá R$ 414,876.73 nas próximas 6 semanas
# A loja número 950 venderá R$ 218,797.19 nas próximas 6 semanas
# A loja número 951 venderá R$ 269,861.39 nas próximas 6 semanas
# A loja número 952 venderá R$ 253,057.79 nas próximas 6 semanas
# A loja número 954 venderá R$ 274,557.09 nas próximas 6 semanas
# A loja número 955 venderá R$ 160,733.29 nas próximas 6 semanas
# A loja número 956 venderá R$ 159,550.54 nas próximas 6 semanas
# A loja número 960 venderá R$ 260,789.98 nas próximas 6 semanas
# A loja número 961 venderá R$ 249,469.75 nas próximas 6 semanas
# A loja número 962 venderá R$ 233,657.30 nas próximas 6 semanas
# A loja número 964 venderá R$ 275,642.85 nas próximas 6 semanas
# A loja número 965 venderá R$ 276,895.33 nas próximas 6 semanas
# A loja número 966 venderá R$ 247,929.79 nas próximas 6 semanas
# A loja número 967 venderá R$ 254,523.86 nas próximas 6 semanas
# A loja número 969 venderá R$ 149,009.93 nas próximas 6 semanas
# A loja número 970 venderá R$ 186,021.17 nas próximas 6 semanas
# A loja número 973 venderá R$ 295,171.35 nas próximas 6 semanas
# A loja número 974 venderá R$ 303,340.00 nas próximas 6 semanas
# A loja número 975 venderá R$ 308,758.52 nas próximas 6 semanas
# A loja número 976 venderá R$ 321,985.53 nas próximas 6 semanas
# A loja número 977 venderá R$ 230,787.57 nas próximas 6 semanas
# A loja número 980 venderá R$ 287,668.25 nas próximas 6 semanas
# A loja número 983 venderá R$ 271,326.41 nas próximas 6 semanas
# A loja número 984 venderá R$ 292,397.94 nas próximas 6 semanas
# A loja número 985 venderá R$ 356,704.49 nas próximas 6 semanas
# A loja número 986 venderá R$ 182,442.57 nas próximas 6 semanas
# A loja número 988 venderá R$ 188,835.44 nas próximas 6 semanas
# A loja número 989 venderá R$ 186,339.35 nas próximas 6 semanas
# A loja número 991 venderá R$ 268,594.88 nas próximas 6 semanas
# A loja número 992 venderá R$ 229,501.03 nas próximas 6 semanas
# A loja número 994 venderá R$ 166,144.82 nas próximas 6 semanas
# A loja número 997 venderá R$ 203,290.25 nas próximas 6 semanas
# A loja número 998 venderá R$ 169,401.00 nas próximas 6 semanas
# A loja número 1000 venderá R$ 240,562.30 nas próximas 6 semanas
# A loja número 1003 venderá R$ 224,250.88 nas próximas 6 semanas
# A loja número 1004 venderá R$ 184,311.55 nas próximas 6 semanas
# A loja número 1005 venderá R$ 285,050.77 nas próximas 6 semanas
# A loja número 1007 venderá R$ 260,951.66 nas próximas 6 semanas
# A loja número 1008 venderá R$ 211,941.30 nas próximas 6 semanas
# A loja número 1009 venderá R$ 182,135.40 nas próximas 6 semanas
# A loja número 1010 venderá R$ 339,872.89 nas próximas 6 semanas
# A loja número 1011 venderá R$ 379,089.62 nas próximas 6 semanas
# A loja número 1012 venderá R$ 242,880.19 nas próximas 6 semanas
# A loja número 1013 venderá R$ 190,437.73 nas próximas 6 semanas
# A loja número 1014 venderá R$ 277,811.51 nas próximas 6 semanas
# A loja número 1015 venderá R$ 255,427.91 nas próximas 6 semanas
# A loja número 1016 venderá R$ 289,206.78 nas próximas 6 semanas
# A loja número 1019 venderá R$ 336,898.82 nas próximas 6 semanas
# A loja número 1020 venderá R$ 269,132.83 nas próximas 6 semanas
# A loja número 1022 venderá R$ 360,661.98 nas próximas 6 semanas
# A loja número 1024 venderá R$ 224,069.05 nas próximas 6 semanas
# A loja número 1025 venderá R$ 293,689.66 nas próximas 6 semanas
# A loja número 1026 venderá R$ 397,491.36 nas próximas 6 semanas
# A loja número 1027 venderá R$ 330,800.38 nas próximas 6 semanas
# A loja número 1028 venderá R$ 199,958.36 nas próximas 6 semanas
# A loja número 1031 venderá R$ 261,200.75 nas próximas 6 semanas
# A loja número 1036 venderá R$ 213,405.36 nas próximas 6 semanas
# A loja número 1037 venderá R$ 246,079.08 nas próximas 6 semanas
# A loja número 1038 venderá R$ 250,134.31 nas próximas 6 semanas
# A loja número 1039 venderá R$ 239,936.30 nas próximas 6 semanas
# A loja número 1040 venderá R$ 317,653.31 nas próximas 6 semanas
# A loja número 1041 venderá R$ 255,696.10 nas próximas 6 semanas
# A loja número 1042 venderá R$ 207,110.40 nas próximas 6 semanas
# A loja número 1044 venderá R$ 286,068.03 nas próximas 6 semanas
# A loja número 1045 venderá R$ 291,927.40 nas próximas 6 semanas
# A loja número 1047 venderá R$ 206,825.29 nas próximas 6 semanas
# A loja número 1048 venderá R$ 256,147.13 nas próximas 6 semanas
# A loja número 1049 venderá R$ 208,717.89 nas próximas 6 semanas
# A loja número 1050 venderá R$ 273,664.22 nas próximas 6 semanas
# A loja número 1051 venderá R$ 236,468.46 nas próximas 6 semanas
# A loja número 1052 venderá R$ 295,611.12 nas próximas 6 semanas
# A loja número 1053 venderá R$ 352,223.43 nas próximas 6 semanas
# A loja número 1054 venderá R$ 212,982.99 nas próximas 6 semanas
# A loja número 1056 venderá R$ 157,813.52 nas próximas 6 semanas
# A loja número 1057 venderá R$ 248,155.35 nas próximas 6 semanas
# A loja número 1058 venderá R$ 260,662.85 nas próximas 6 semanas
# A loja número 1059 venderá R$ 284,588.27 nas próximas 6 semanas
# A loja número 1060 venderá R$ 318,573.36 nas próximas 6 semanas
# A loja número 1061 venderá R$ 315,479.15 nas próximas 6 semanas
# A loja número 1062 venderá R$ 174,782.76 nas próximas 6 semanas
# A loja número 1063 venderá R$ 216,088.23 nas próximas 6 semanas
# A loja número 1064 venderá R$ 411,701.80 nas próximas 6 semanas
# A loja número 1065 venderá R$ 189,955.16 nas próximas 6 semanas
# A loja número 1066 venderá R$ 373,264.39 nas próximas 6 semanas
# A loja número 1067 venderá R$ 255,891.77 nas próximas 6 semanas
# A loja número 1068 venderá R$ 187,807.11 nas próximas 6 semanas
# A loja número 1070 venderá R$ 270,233.06 nas próximas 6 semanas
# A loja número 1071 venderá R$ 249,605.09 nas próximas 6 semanas
# A loja número 1072 venderá R$ 268,330.73 nas próximas 6 semanas
# A loja número 1073 venderá R$ 311,381.24 nas próximas 6 semanas
# A loja número 1076 venderá R$ 165,879.36 nas próximas 6 semanas
# A loja número 1077 venderá R$ 181,695.84 nas próximas 6 semanas
# A loja número 1078 venderá R$ 291,450.51 nas próximas 6 semanas
# A loja número 1079 venderá R$ 314,138.68 nas próximas 6 semanas
# A loja número 1080 venderá R$ 360,276.81 nas próximas 6 semanas
# A loja número 1083 venderá R$ 213,126.92 nas próximas 6 semanas
# A loja número 1084 venderá R$ 234,163.89 nas próximas 6 semanas
# A loja número 1086 venderá R$ 192,390.54 nas próximas 6 semanas
# A loja número 1087 venderá R$ 217,379.40 nas próximas 6 semanas
# A loja número 1088 venderá R$ 182,825.61 nas próximas 6 semanas
# A loja número 1089 venderá R$ 378,997.39 nas próximas 6 semanas
# A loja número 1091 venderá R$ 331,488.58 nas próximas 6 semanas
# A loja número 1092 venderá R$ 399,346.83 nas próximas 6 semanas
# A loja número 1094 venderá R$ 212,536.77 nas próximas 6 semanas
# A loja número 1096 venderá R$ 204,124.19 nas próximas 6 semanas
# A loja número 1097 venderá R$ 384,420.98 nas próximas 6 semanas
# A loja número 1099 venderá R$ 243,873.34 nas próximas 6 semanas
# A loja número 1100 venderá R$ 273,741.39 nas próximas 6 semanas
# A loja número 1101 venderá R$ 364,007.25 nas próximas 6 semanas
# A loja número 1102 venderá R$ 254,839.92 nas próximas 6 semanas
# A loja número 1103 venderá R$ 184,458.69 nas próximas 6 semanas
# A loja número 1104 venderá R$ 187,612.93 nas próximas 6 semanas
# A loja número 1105 venderá R$ 190,304.73 nas próximas 6 semanas
# A loja número 1106 venderá R$ 188,391.23 nas próximas 6 semanas
# A loja número 1107 venderá R$ 236,442.88 nas próximas 6 semanas
# A loja número 1109 venderá R$ 193,837.99 nas próximas 6 semanas
# A loja número 1111 venderá R$ 208,980.42 nas próximas 6 semanas
# A loja número 1112 venderá R$ 376,476.08 nas próximas 6 semanas
# A loja número 1113 venderá R$ 267,849.83 nas próximas 6 semanas
# A loja número 1114 venderá R$ 885,676.74 nas próximas 6 semanas
# A loja número 1115 venderá R$ 260,433.92 nas próximas 6 semanas

# %%
#download to csv file
#d1.to_csv (r'/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/sales_predction2.csv', index = False, header=True)

# %%
#download to xlsx file
#d1.to_excel(r'/Users/deboragoncalves/Documents/repos/Data_science_em_producao/Projeto_rossmann_store_sales/sales_predction1.xlsx', index=False)
